# %% [markdown]
# # Libraries + Torch check

# %%
import pandas as pd
import requests
import json
from pathlib import Path
import re
from datetime import date
import time
import os
from fastai.tabular import *
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model
import sklearn.metrics
from sklearn.model_selection import train_test_split
import math

# %%
import torch

# %%
torch.cuda.device(0)

# %%
torch.cuda.get_device_name(0)
# Out:
# 'GeForce RTX 2080'

# %% [markdown]
# # Data Retrieval

# %%
cleaned_item_names = [name[:-10] for name in list(os.walk(r'data/wiki_prices'))[0][2]]

# %%
cleaned_item_names[0:5]
# Out:
# ['Potato%20seed', 'Tin%20ore', 'Gout%20tuber', 'Bronze%20bolts', 'Gold%20seal']

# %%
pd.Series(cleaned_item_names).to_csv('./data/cleaned_item_names', index=False, header=False)

# %%
len(cleaned_item_names)
# Out:
# 3147

# %%
# cleaned_item_names

# %%
#TODO add last day's price by including the last row even though it doesn't have volume

# %%
def get_item_df(item_name, sleppy_time=1):
    base_url = r"https://oldschool.runescape.wiki/api.php?action=query&prop=revisions&rvprop=content&format=json&titles=Module%3AExchange%2F"
    postfix_url = r"%2FData"
    full_url = f'{base_url}{item_name}{postfix_url}'
    resp = requests.get(full_url)
    jsond = resp.json()
    try:
        regex_text = jsond['query']['pages'][next(iter(jsond['query']['pages'].keys()))]['revisions'][0]['*']
        #get all of the ones that have volume as well as price
        m = re.findall(r'[\d]+:[\d]+:[\d]+', regex_text)
        item_df = pd.DataFrame()
        item_df['dt'] = [int(string.split(':')[0]) for string in m]
        item_df[f'{item_name} price'] = [int(string.split(':')[1]) for string in m]
        item_df[f'{item_name} volume'] = [int(string.split(':')[2]) for string in m]
        item_df['date_obj'] = item_df['dt'].apply(lambda x: date.fromtimestamp(x))
        #take the ones that just have price so we can get the most recent price as well
        n = re.findall(r'[\d]+:[\d]+', regex_text)
        last_time = date.fromtimestamp(int(n[-1].split(':')[0]))
        last_price = int(n[-1].split(':')[1])
        item_df.loc[-1, 'date_obj'] = last_time
        item_df.loc[-1, f'{item_name} price'] = last_price
        item_df = item_df.fillna(method='ffill')
        item_df.set_index('date_obj', inplace=True)
        item_df = item_df.drop('dt', axis=1)
        return item_df
    except:
        pass

# %%
item_name = cleaned_item_names[300]

# %%
item_name
# Out:
# "Guthan's%20armour%20set"

# %%
base_url = r"https://oldschool.runescape.wiki/api.php?action=query&prop=revisions&rvprop=content&format=json&titles=Module%3AExchange%2F"
postfix_url = r"%2FData"
full_url = f'{base_url}{item_name}{postfix_url}'
resp = requests.get(full_url)
jsond = resp.json()
regex_text = jsond['query']['pages'][next(iter(jsond['query']['pages'].keys()))]['revisions'][0]['*']
#get all of the ones that have volume as well as price
m = re.findall(r'[\d]+:[\d]+:[\d]+', regex_text)
item_df = pd.DataFrame()
item_df['dt'] = [int(string.split(':')[0]) for string in m]
item_df[f'{item_name} price'] = [int(string.split(':')[1]) for string in m]
item_df[f'{item_name} volume'] = [int(string.split(':')[2]) for string in m]

item_df['date_obj'] = item_df['dt'].apply(lambda x: date.fromtimestamp(x))
n = re.findall(r'[\d]+:[\d]+', regex_text)
last_time = date.fromtimestamp(int(n[-1].split(':')[0]))
last_price = int(n[-1].split(':')[1])
item_df.loc[-1, 'date_obj'] = last_time
item_df.loc[-1, f'{item_name} price'] = last_price
item_df = item_df.fillna(method='ffill')
item_df.set_index('date_obj', inplace=True)
item_df = item_df.drop('dt', axis=1)
item_df
# Out:
#             Guthan's%20armour%20set price  Guthan's%20armour%20set volume
# date_obj
# 2018-12-25                      5119439.0                          1990.0
# 2018-12-26                      5218130.0                          4037.0
# 2018-12-27                      5445262.0                          1729.0
# 2018-12-28                      5542777.0                          4316.0
# 2018-12-29                      5766101.0                          2349.0
# ...                                   ...                             ...
# 2020-07-28                      2785436.0                          2836.0
# 2020-07-29                      2767201.0                          3813.0
# 2020-07-30                      2731217.0                          1411.0
# 2020-07-31                      2734384.0                          3862.0
# 2020-08-01                      2767411.0                          3862.0
#
# [581 rows x 2 columns]

# %%
n = re.findall(r'[\d]+:[\d]+', regex_text)

# %%
last_time = date.fromtimestamp(int(n[-1].split(':')[0]))
last_price = int(n[-1].split(':')[1])
last_price
# Out:
# 2767411

# %%
regex_text
# Out:
# "return {\n    '1427414400:15042149',\n    '1427500800:15042149',\n    '1427587200:15090839',\n    '1427673600:15021063',\n    '1427760000:15283341',\n    '1427846400:15386361',\n    '1427932800:15532423',\n    '1428019200:15610460',\n    '1428105600:15751054',\n    '1428192000:15880435',\n    '1428278400:15865348',\n    '1428364800:15883442',\n    '1428451200:15756535',\n    '1428537600:15556866',\n    '1428624000:15249186',\n    '1428710400:14938976',\n    '1428796800:14939327',\n    '1428883200:14947727',\n    '1428969600:14891535',\n    '1429056000:14912514',\n    '1429142400:14904533',\n    '1429228800:14809210',\n    '1429315200:14759701',\n    '1429401600:14746040',\n    '1429488000:14798700',\n    '1429574400:14933504',\n    '1429660800:14959340',\n    '1429747200:14927315',\n    '1429833600:14935646',\n    '1429920000:15074110',\n    '1430006400:15084087',\n    '1430092800:15364608',\n    '1430179200:15927018',\n    '1430265600:15978988',\n    '1430352000:15978988',\n    '1430438400:15847810',\n    '1430524800:15823427',\n    '1430611200:16110163',\n    '1430697600:16257314',\n    '1430784000:16396869',\n    '1430870400:16309439',\n    '1430956800:16168661',\n    '1431043200:16234488',\n    '1431129600:16241817',\n    '1431216000:16246156',\n    '1431302400:15968799',\n    '1431388800:15558768',\n    '1431475200:15619188',\n    '1431561600:15511548',\n    '1431648000:15317555',\n    '1431734400:15134510',\n    '1431820800:15007625',\n    '1431907200:14853933',\n    '1431993600:14706254',\n    '1432080000:14544728',\n    '1432166400:14203976',\n    '1432252800:13564371',\n    '1432339200:12914500',\n    '1432425600:13305255',\n    '1432512000:13847370',\n    '1432598400:14066861',\n    '1432684800:14331092',\n    '1432771200:14576509',\n    '1432857600:14655522',\n    '1432944000:14590004',\n    '1433030400:14544211',\n    '1433116800:14274196',\n    '1433203200:14075598',\n    '1433289600:13639773',\n    '1433376000:13289450',\n    '1433462400:13184619',\n    '1433548800:13172626',\n    '1433635200:13415753',\n    '1433721600:13751332',\n    '1433808000:14065639',\n    '1433894400:14478119',\n    '1433980800:14409371',\n    '1434067200:14152734',\n    '1434153600:13973189',\n    '1434240000:13981784',\n    '1434326400:13970468',\n    '1434412800:13892915',\n    '1434499200:14008709',\n    '1434585600:13945036',\n    '1434672000:13987760',\n    '1434758400:14264902',\n    '1434844800:14220885',\n    '1434931200:14304646',\n    '1435017600:14254090',\n    '1435104000:14431025',\n    '1435190400:14480668',\n    '1435276800:14592109',\n    '1435363200:14753653',\n    '1435449600:14657576',\n    '1435536000:14668236',\n    '1435622400:14688422',\n    '1435708800:14827176',\n    '1435795200:14947594',\n    '1435881600:14957407',\n    '1435968000:14930995',\n    '1436054400:14645967',\n    '1436140800:14571658',\n    '1436227200:14353422',\n    '1436313600:14258514',\n    '1436400000:14218579',\n    '1436486400:14182483',\n    '1436572800:14099334',\n    '1436659200:14004900',\n    '1436745600:13836846',\n    '1436832000:13526083',\n    '1436918400:13503769',\n    '1437004800:13831812',\n    '1437091200:14012178',\n    '1437177600:14258515',\n    '1437264000:14263899',\n    '1437350400:14124859',\n    '1437436800:14044584',\n    '1437523200:13893428',\n    '1437609600:13891579',\n    '1437696000:13847208',\n    '1437782400:13971353',\n    '1437868800:14128468',\n    '1437955200:14220887',\n    '1438041600:14450799',\n    '1438128000:14601653',\n    '1438214400:14709928',\n    '1438300800:14738863',\n    '1438387200:14792780',\n    '1438473600:14814464',\n    '1438560000:14902324',\n    '1438646400:15074388',\n    '1438732800:15405476',\n    '1438819200:15430070',\n    '1438905600:15328966',\n    '1438992000:15281975',\n    '1439078400:15296890',\n    '1439164800:15251384',\n    '1439251200:15134474',\n    '1439337600:15196425',\n    '1439424000:15213031',\n    '1439510400:15097899',\n    '1439596800:14985802',\n    '14396832 ...

# %%
item_name = cleaned_item_names[300]

# %%
    base_url = r"https://oldschool.runescape.wiki/api.php?action=query&prop=revisions&rvprop=content&format=json&titles=Module%3AExchange%2F"
    postfix_url = r"%2FData"
    full_url = f'{base_url}{item_name}{postfix_url}'
    full_url
# Out:
# "https://oldschool.runescape.wiki/api.php?action=query&prop=revisions&rvprop=content&format=json&titles=Module%3AExchange%2FGuthan's%20armour%20set%2FData"

# %%
def retrieve_dfs(xslice = True):
    if xslice:
        item_dfs = [get_item_df(item_name,1) for item_name in cleaned_item_names[40:45]]
    else:
        item_dfs = [get_item_df(item_name,1) for item_name in cleaned_item_names]
    return item_dfs

# %%
#item_dfs = retrieve_dfs(False)

# %%
def save_dfs(item_dfs):
    for df in item_dfs:
        try:
            df.to_csv(f'./data/wiki_prices/{df.columns[0]}.csv')
        except:
            pass

# %%
#save_dfs(item_dfs)

# %%
def load_dfs(drop_blank=True):
    item_dfs = []
    for name in list(os.walk('./data/wiki_prices'))[0][2]:
        df = pd.read_csv(f'./data/wiki_prices/{name}')
        df = df.set_index(df.columns[0])
#         if drop_blank:
#             if df.empty:
#                 item_dfs.append(df)
#         else:
#             item_dfs.append(df)
        item_dfs.append(df)
    return item_dfs

# %%
item_dfs = load_dfs()

# %%
len(item_dfs)
# Out:
# 3147

# %%
type(item_dfs)
# Out:
# list

# %%
cleaned_item_names[0]
# Out:
# 'Potato%20seed'

# %%
for item_df in item_dfs:
    try:
        col = item_df.columns[0]
    except:
        invalid_dfs += 1 
        print(item_df)

# %%
retrieved_names = [item_df.columns[0][:-6] for item_df in item_dfs]

# %%
len(retrieved_names)
# Out:
# 3147

# %%
len(item_dfs)
# Out:
# 3147

# %%
df = pd.DataFrame({'name': retrieved_names, 'price_df': item_dfs})

# %% [markdown]
# # Feature creation

# %%
#item_df_training = tl_df['price_df'][300]

# %%
days_back = 90

rolling_averages = [3,7,14,21,30,60,90]

days_ahead_to_predict = 4

# %%
def create_predictive_features(price_df):
    item_df_training = price_df
    item_name = item_df_training.columns[0]
    for i in range(days_back):
        item_df_training[f'{item_name} {i} days ago'] = item_df_training[item_name].shift(i)
    for i in range(days_back):
        item_df_training[f'{item_name} {i} delta days ago'] = item_df_training[item_name].shift(i) - item_df_training[item_name]
    for rolling_average in rolling_averages:
        item_df_training[f'{item_name} {rolling_average} day rolling average'] = item_df_training[item_name].rolling(rolling_average).mean()
    for rolling_average in rolling_averages:
        item_df_training[f'{item_name} delta {rolling_average} day rolling average'] = item_df_training[item_name] - item_df_training[f'{item_name} {rolling_average} day rolling average']
    item_df_training['Y'] = item_df_training[item_name].shift(-1*days_ahead_to_predict)
    return item_df_training

# %%
#price_df = tl_df['price_df'][300]

# %%
def trim_df(item_df_training):
    trimmed_df = item_df_training.dropna(how='any')
    return trimmed_df

# %% [markdown]
# # SGD LR

# %%
def create_model(tl_df_row):
    trimmed_df = tl_df_row['trimmed_df']
    try:
        X = trimmed_df.drop(['Y'], axis=1)
        y = trimmed_df['Y']
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, shuffle=False)
        regr = linear_model.LinearRegression()
        regr.fit(X_train, y_train)
        y_pred = regr.predict(X_test)
        mean_squared_error = sklearn.metrics.mean_squared_error(y_test, y_pred)
        r2_score = sklearn.metrics.r2_score(y_test, y_pred)
        return (regr, y_pred, y_test, mean_squared_error, r2_score)
    except:
        return (0, 0, 0, 0, 0)

# %%
#plt.scatter(y_test, y_pred)

# %%
model_cols = tl_df.apply(create_model, axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-b06cc9ce2a52> in <module>
# ----> 1 model_cols = tl_df.apply(create_model, axis=1)
#
# NameError: name 'tl_df' is not defined

# %% [markdown]
# # "Backtest"

# %%
starting_cash = 10**7

# %%
slippage = 0
thresh_buy = 0.00
thresh_sell = 0
max_volume_buy = 0.01

# %%
def should_buy(row):
    if row['perc predicted increase'] > thresh_buy:
        return True

def should_sell(row):
    if row['perc predicted increase'] < thresh_sell:
        return True
    
def buy_price(row):
    return row['current_price']

def sell_price(row):
    return row['current_price']

def max_buy(row):
    d_stock = max(
        min(
        (row['starting_cash']//buy_price(row)),
        math.floor(row['volume']*max_volume_buy)
        ),
        0
    )
    d_cash = -1 * d_stock * buy_price(row)
    return (d_stock, d_cash)

def max_sell(row):
    d_stock = -1 * max(
        0,
        min(row['starting_stock'],
        math.floor(row['volume'] * max_volume_buy)
        )
    )
    d_cash = d_stock *-1 * sell_price(row)
    return (d_stock, d_cash)

# %%
def get_ending_cash(record_df):
    last_row = record_df.iloc[-1,:]
    cash = last_row['ending_cash']
    cash += sell_price(last_row) * last_row['ending_stock']
    return cash

# %%
def create_backtest_df(tl_df_row):
    try:
        y_pred = tl_df_row['y_pred']
        y_test = tl_df_row['y_test']
        item_df_training = tl_df_row['item_df_training']
        item_name = tl_df_row['name']

        bt_df = pd.concat([pd.Series(y_pred, index= y_test.index, name='Prediction'), y_test.rename(index='Y')], axis=1)
        bt_df['Y + 1'] = bt_df['Y'].shift(-1)
        bt_df['Y - 1'] = bt_df['Y'].shift(1)


        bt_df = bt_df.fillna(method='ffill').fillna(method='bfill')

        volume_column = f'{item_name} volume'
        volume = item_df_training[volume_column]

        bt_df = bt_df.join(item_df_training[volume_column].rename(index='volume'))
        bt_df = bt_df.join(item_df_training[f'{item_name} price'].rename(index='current_price'))
        bt_df['perc predicted increase'] = (bt_df['Prediction'] - bt_df['current_price'])/bt_df['current_price']

        bt_df['starting_stock'] = 0
        bt_df['starting_cash'] = 0
        bt_df['ending_stock'] = 0
        bt_df['ending_cash'] = 0

        bt_df.loc[bt_df.index[0], 'starting_cash'] = starting_cash
        bt_df.loc[bt_df.index[0], 'ending_cash'] = starting_cash

        bt_df['action'] = ''

        copy_df = bt_df.copy()
        record_df = bt_df.copy()

        first_row = True
        for i, row in copy_df.iterrows():
            current_row = row
            if first_row:
                prev_row = current_row
                first_row = False
                continue
            current_row['starting_cash'] = prev_row['ending_cash']
            current_row['starting_stock'] = prev_row['ending_stock']
            cash = current_row['starting_cash']
            stock = current_row['starting_stock']
            if should_buy(current_row):
                d_stock, d_cash = max_buy(current_row)
                cash += d_cash
                stock += d_stock
                current_row['action'] = f'Buying + {d_stock} stock, - {d_cash} cash'
            elif should_sell(row):
                d_stock, d_cash = max_sell(current_row)
                cash += d_cash
                stock += d_stock
                current_row['action'] = f'Selling + {d_stock} stock, + {d_cash} cash'
            else:
                current_row['action'] = 'hold'
            current_row['ending_cash'] = cash
            current_row['ending_stock'] = stock
            record_df.loc[i, :] = current_row
            prev_row = current_row
        roi = get_ending_cash(record_df)/starting_cash
        last_perc_prediction = bt_df
        return (roi, record_df)
    except:
        return (0, 0)

# %% [markdown]
# # Predict for right now

# %%
def make_predictions(tl_df_row):
    try:
        item_name = tl_df_row['name']
        regr = tl_df_row['regr']
        item_df_training = tl_df_row['item_df_training']
        current_price = item_df_training.loc[item_df_training.index[-1], f'{item_name} price']
        pred_price = regr.predict(np.array(item_df_training.drop('Y', axis=1).loc[item_df_training.index[-1],:]).reshape(1, -1))[0]
        perc_pred_increase = (pred_price - current_price)/(current_price)
        last_day = item_df_training.index[-1]
        return (perc_pred_increase, last_day)
    except:
        return(0, 0)

# %% [markdown]
# # Filter and find trades

# %%
r2_score_thresh = .85
roi_thresh = 1.05
perc_pred_increase_thresh = 0.03

# %%
batch_size = 100

# %%
df_list = []

# %%
bought = pd.read_csv('data/bought')
bought.loc[4] = "Mithril%20kiteshield"

# %%
tl_df

# %%
bought['name'].values
# Out:
# array(['Icy%20basalt', 'Black%20shield%20(h1)', 'Saradomin%20bracers', 'Merfolk%20trident', 'Mithril%20kiteshield'],
#       dtype=object)

# %%
for i in range(0,df.shape[0],batch_size):
    tl_df = df.iloc[i:i+100,:]
    
    tl_df['item_df_training'] = tl_df['price_df'].apply(create_predictive_features)

    tl_df['trimmed_df'] = tl_df['item_df_training'].apply(trim_df)

    tl_df['regr'], tl_df['y_pred'], tl_df['y_test'], tl_df['mean_squared_error'], tl_df['r2_score'] = zip(*tl_df.apply(create_model, axis=1))


    tl_df['roi'], tl_df['record_df'] = zip(*tl_df.apply(create_backtest_df, axis=1))


    tl_df.sort_values(by='roi', ascending = False)

    tl_df['perc_pred_increase'], tl_df['last_day'] = zip(*tl_df.apply(make_predictions, axis=1))


    filter_tl_df = tl_df.copy()

    filter_tl_df = filter_tl_df.dropna(how='any')

    filter_tl_df =filter_tl_df.loc[filter_tl_df['r2_score'].apply(lambda x: type(x)) != list]

    filter_tl_df = filter_tl_df.loc[filter_tl_df['r2_score'] > r2_score_thresh]

    print(filter_tl_df.shape)

    filter_tl_df = filter_tl_df.loc[filter_tl_df['roi'] > roi_thresh]

    print(filter_tl_df.shape)

    filter_tl_df = filter_tl_df.loc[
            (filter_tl_df['perc_pred_increase'] > perc_pred_increase_thresh) \
        | (filter_tl_df['name'].isin(bought['name']))
                                   ]

    print(filter_tl_df.shape)

    print(filter_tl_df)
    df_list.append(filter_tl_df)
# Out:
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (22, 13)
# (2, 13)
# (0, 13)
# Empty DataFrame
# Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
# Index: []
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (26, 13)
# (2, 13)
# (1, 13)
#                            name  \
# 162  Black%20wizard%20hat%20(g)
#
#                                               price_df  \
# 162              Black%20wizard%20hat%20(g) price  ...
#
#                                       item_df_training  \
# 162              Black%20wizard%20hat%20(g) price  ...
#
#                                             trimmed_df                regr  \
# 162              Black%20wizard%20hat%20(g) price  ...  LinearRegression()
#
#                                                 y_pred  \
# 162  [391487.9598214286, 377538.5066964286, 385509....
#
#                                                 y_test  mean_squared_error  \
# 162  date_obj
# 2020-04-04    384204.0
# 2020-04-06    ...        1.042362e+08
#
#      r2_score       roi                                          record_df  \
# 162  0.964714  1.130223                 Prediction         Y     Y + 1 ...
#
#      perc_pred_increase    last_day
# 162            0.044321  2020-07-31
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (24, 13)
# (3, 13)
# (0, 13)
# Empty DataFrame
# Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
# Index: []
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (23, 13)
# (0, 13)
# (0, 13)
# Empty DataFrame
# Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
# Index: []
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (20, 13)
# (1, 13)
# (1, 13)
#                       name                                           price_df  \
# 403  Black%20shield%20(h1)              Black%20shield%20(h1) price  Black...
#
#                                       item_df_training  \
# 403              Black%20shield%20(h1) price  Black...
#
#                                             trimmed_df                regr  \
# 403              Black%20shield%20(h1) price  Black...  LinearRegression()
#
#                                                 y_pred  \
# 403  [2756.806000845773, 2730.172013419015, 2602.58...
#
#                                                 y_test  mean_squared_error  \
# 403  date_obj
# 2020-04-05    2526.0
# 2020-04-06    25...       136983.799702
#
#      r2_score       roi                                          record_df  \
# 403  0.936316  1.061357               Prediction       Y   Y + 1   Y - ...
#
#      perc_pred_increase    last_day
# 403            0.061413  2020-07-31
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (26, 13)
# (5, 13)
# (0, 13)
# Empty DataFrame
# Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
# Index: []
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (27, 13)
# (2, 13)
# (0, 13)
# Empty DataFrame
# Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
# Index: []
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (27, 13)
# (2, 13)
# (0, 13)
# Empty DataFrame
# Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
# Index: []
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (31, 13)
# (5, 13)
# (0, 13)
# Empty DataFrame
# Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
# Index: []
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (25, 13)
# (2, 13)
# (1, 13)
#                     name                                           price_df  \
# 937  White%20lily%20seed              White%20lily%20seed price  White%2...
#
#                                       item_df_training  \
# 937              White%20lily%20seed price  White%2...
#
#                                             trimmed_df                regr  \
# 937              White%20lily%20seed price  White%2...  LinearRegression()
#
#                                                 y_pred  \
# 937  [3939.4816059313325, 3761.1046528063325, 3443....
#
#                                                 y_test  mean_squared_error  \
# 937  date_obj
# 2020-04-22    3469.0
# 2020-04-23    34...        51839.678206
#
#      r2_score       roi                                          record_df  \
# 937  0.852554  1.218303               Prediction       Y   Y + 1   Y - ...
#
#      perc_pred_increase    last_day
# 937            0.030701  2020-07-31
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (24, 13)
# (2, 13)
# (1, 13)
#                        name  \
# 1010  Maple%20longbow%20(u)
#
#                                                price_df  \
# 1010              Maple%20longbow%20(u) price  Maple...
#
#                                        item_df_training  \
# 1010              Maple%20longbow%20(u) price  Maple...
#
#                                              trimmed_df                regr  \
# 1010              Maple%20longbow%20(u) price  Maple...  LinearRegression()
#
#                                                  y_pred  \
# 1010  [37.14832560946309, 37.872298555868504, 37.592...
#
#                                                  y_test  mean_squared_error  \
# 1010  date_obj
# 2020-02-20    36.0
# 2020-02-21    35.0...            7.415308
#
#       r2_score       roi                                          record_df  \
# 1010  0.956685  2.403655              Prediction     Y  Y + 1  Y - 1   v...
#
#       perc_pred_increase    last_day
# 1010            0.045528  2020-07-31
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (23, 13)
# (2, 13)
# (2, 13)
#                 name                                           price_df  \
# 1159    Icy%20basalt              Icy%20basalt price  Icy%20basalt v...
# 1178  Ankou%20gloves              Ankou%20gloves price  Ankou%20glov...
#
#                                        item_df_training  \
# 1159              Icy%20basalt price  Icy%20basalt v...
# 1178              Ankou%20gloves price  Ankou%20glov...
#
#                                              trimmed_df                regr  \
# 1159              Icy%20basalt price  Icy%20basalt v...  LinearRegression()
# 1178              Ankou%20gloves price  Ankou%20glov...  LinearRegression()
#
#                                                  y_pred  \
# 1159  [1126.4144560558962, 1028.17171923949, 1067.33...
# 1178  [3136674.1088888887, 3204562.1088888887, 31773...
#
#                                                  y_test  mean_squared_error  \
# 1159  date_obj
# 2020-04-16    1020.0
# 2020-04-17     9...        5.190277e+03
# 1178  date_obj
# 2020-04-04    3123496.0
# 2020-04-05   ...        2.232945e+10
#
#       r2_score       roi                                          record_df  \
# 1159  0.858357  1.060704               Prediction       Y   Y + 1   Y - ...
# 1178  0.910772  1.493479                Prediction          Y      Y + 1...
#
#       perc_pred_increase    last_day
# 1159            0.089413  2020-07-31
# 1178            0.035729  2020-07-31
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (24, 13)
# (0, 13)
# (0, 13)
# Empty DataFrame
# Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
# Index: []
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (33, 13)
# (2, 13)
# (1, 13)
#                    name                                           price_df  \
# 1338  Merfolk%20trident              Merfolk%20trident price  Merfolk%2...
#
#                                        item_df_training  \
# 1338              Merfolk%20trident price  Merfolk%2...
#
#                                              trimmed_df                regr  \
# 1338              Merfolk%20trident price  Merfolk%2...  LinearRegression()
#
#                                                  y_pred  \
# 1338  [866041.2462962962, 864647.6212962962, 849144....
#
#                                                  y_test  mean_squared_error  \
# 1338  date_obj
# 2020-04-16    863959.0
# 2020-04-17    ...        1.101948e+09
#
#       r2_score       roi                                          record_df  \
# 1338  0.905511  1.078465                 Prediction         Y     Y + 1 ...
#
#       perc_pred_increase    last_day
# 1338            0.050825  2020-07-31
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (31, 13)
# (0, 13)
# (0, 13)
# Empty DataFrame
# Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
# Index: []
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (34, 13)
# (4, 13)
# (1, 13)
# ...
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (32, 13)
# (3, 13)
# (0, 13)
# Empty DataFrame
# Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
# Index: []
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (17, 13)
# (0, 13)
# (0, 13)
# Empty DataFrame
# Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
# Index: []
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (25, 13)
# (5, 13)
# (1, 13)
#                     name                                           price_df  \
# 2850  Mist%20battlestaff              Mist%20battlestaff price  Mist%20b...
#
#                                        item_df_training  \
# 2850              Mist%20battlestaff price  Mist%20b...
#
#                                              trimmed_df                regr  \
# 2850              Mist%20battlestaff price  Mist%20b...  LinearRegression()
#
#                                                  y_pred  \
# 2850  [93545.97978395062, 96343.47978395062, 99162.1...
#
#                                                  y_test  mean_squared_error  \
# 2850  date_obj
# 2020-04-16     99418.0
# 2020-04-17    ...        3.662679e+07
#
#       r2_score      roi                                          record_df  \
# 2850  0.871425  1.34245                 Prediction         Y     Y + 1 ...
#
#       perc_pred_increase    last_day
# 2850            0.040803  2020-07-31
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (33, 13)
# (1, 13)
# (0, 13)
# Empty DataFrame
# Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
# Index: []
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (21, 13)
# (4, 13)
# (2, 13)
#                  name                                           price_df  \
# 3020  Mole%20slippers              Mole%20slippers price  Mole%20slip...
# 3046       Oak%20logs              Oak%20logs price  Oak%20logs volum...
#
#                                        item_df_training  \
# 3020              Mole%20slippers price  Mole%20slip...
# 3046              Oak%20logs price  Oak%20logs volum...
#
#                                              trimmed_df                regr  \
# 3020              Mole%20slippers price  Mole%20slip...  LinearRegression()
# 3046              Oak%20logs price  Oak%20logs volum...  LinearRegression()
#
#                                                  y_pred  \
# 3020  [102341.72696834416, 105307.29728084416, 10637...
# 3046  [17.794087259736298, 17.302686911321317, 17.83...
#
#                                                  y_test  mean_squared_error  \
# 3020  date_obj
# 2020-05-10    101458.0
# 2020-05-11    ...        2.095884e+08
# 3046  date_obj
# 2020-02-20     18.0
# 2020-02-21     17...        9.906002e+01
#
#       r2_score       roi                                          record_df  \
# 3020  0.958967  1.702503                 Prediction         Y     Y + 1 ...
# 3046  0.949737  6.800254              Prediction      Y  Y + 1  Y - 1   ...
#
#       perc_pred_increase    last_day
# 3020            0.047278  2020-07-31
# 3046            0.044258  2020-07-31
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# (17, 13)
# (2, 13)
# (0, 13)
# Empty DataFrame
# Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
# Index: []
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()

# %%
filter_tl_df
# Out:
# Empty DataFrame
# Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
# Index: []

# %%
df_list
# Out:
# [Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#                             name  \
#  162  Black%20wizard%20hat%20(g)
#
#                                                price_df  \
#  162              Black%20wizard%20hat%20(g) price  ...
#
#                                        item_df_training  \
#  162              Black%20wizard%20hat%20(g) price  ...
#
#                                              trimmed_df                regr  \
#  162              Black%20wizard%20hat%20(g) price  ...  LinearRegression()
#
#                                                  y_pred  \
#  162  [391487.9598214286, 377538.5066964286, 385509....
#
#                                                  y_test  mean_squared_error  \
#  162  date_obj
#  2020-04-04    384204.0
#  2020-04-06    ...        1.042362e+08
#
#       r2_score       roi                                          record_df  \
#  162  0.964714  1.130223                 Prediction         Y     Y + 1 ...
#
#       perc_pred_increase    last_day
#  162            0.044321  2020-07-31  ,
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#                        name                                           price_df  \
#  403  Black%20shield%20(h1)              Black%20shield%20(h1) price  Black...
#
#                                        item_df_training  \
#  403              Black%20shield%20(h1) price  Black...
#
#                                              trimmed_df                regr  \
#  403              Black%20shield%20(h1) price  Black...  LinearRegression()
#
#                                                  y_pred  \
#  403  [2756.806000845773, 2730.172013419015, 2602.58...
#
#                                                  y_test  mean_squared_error  \
#  403  date_obj
#  2020-04-05    2526.0
#  2020-04-06    25...       136983.799702
#
#       r2_score       roi                                          record_df  \
#  403  0.936316  1.061357               Prediction       Y   Y + 1   Y - ...
#
#       perc_pred_increase    last_day
#  403            0.061413  2020-07-31  ,
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#                      name                                           price_df  \
#  937  White%20lily%20seed              White%20lily%20seed price  White%2...
#
#                                        item_df_training  \
#  937              White%20lily%20seed price  White%2...
#
#                                              trimmed_df                regr  \
#  937              White%20lily%20seed price  White%2...  LinearRegression()
#
#                                                  y_pred  \
#  937  [3939.4816059313325, 3761.1046528063325, 3443....
#
#                                                  y_test  mean_squared_error  \
#  937  date_obj
#  2020-04-22    3469.0
#  2020-04-23    34...        51839.678206
#
#       r2_score       roi                                          record_df  \
#  937  0.852554  1.218303               Prediction       Y   Y + 1   Y - ...
#
#       perc_pred_increase    last_day
#  937            0.030701  2020-07-31  ,
#                         name  \
#  1010  Maple%20longbow%20(u)
#
#                                                 price_df  \
#  1010              Maple%20longbow%20(u) price  Maple...
#
#                                         item_df_training  \
#  1010              Maple%20longbow%20(u) price  Maple...
#
#                                               trimmed_df                regr  \
#  1010              Maple%20longbow%20(u) price  Maple...  LinearRegression()
#
#                                                   y_pred  \
#  1010  [37.14832560946309, 37.872298555868504, 37.592...
#
#                                                   y_test  mean_squared_error  \
#  1010  date_obj
#  2020-02-20    36.0
#  2020-02-21    35.0...            7.415308
#
#        r2_score       roi                                          record_df  \
#  1010  0.956685  2.403655              Prediction     Y  Y + 1  Y - 1   v...
#
#        perc_pred_increase    last_day
#  1010            0.045528  2020-07-31  ,
#                  name                                           price_df  \
#  1159    Icy%20basalt              Icy%20basalt price  Icy%20basalt v...
#  1178  Ankou%20gloves              Ankou%20gloves price  Ankou%20glov...
#
#                                         item_df_training  \
#  1159              Icy%20basalt price  Icy%20basalt v...
#  1178              Ankou%20gloves price  Ankou%20glov...
#
#                                               trimmed_df                regr  \
#  1159              Icy%20basalt price  Icy%20basalt v...  LinearRegression()
#  1178              Ankou%20gloves price  Ankou%20glov...  LinearRegression()
#
#                                                   y_pred  \
#  1159  [1126.4144560558962, 1028.17171923949, 1067.33...
#  1178  [3136674.1088888887, 3204562.1088888887, 31773...
#
#                                                   y_test  mean_squared_error  \
#  1159  date_obj
#  2020-04-16    1020.0
#  2020-04-17     9...        5.190277e+03
#  1178  date_obj
#  2020-04-04    3123496.0
#  2020-04-05   ...        2.232945e+10
#
#        r2_score       roi                                          record_df  \
#  1159  0.858357  1.060704               Prediction       Y   Y + 1   Y - ...
#  1178  0.910772  1.493479                Prediction          Y      Y + 1...
#
#        perc_pred_increase    last_day
#  1159            0.089413  2020-07-31
#  1178            0.035729  2020-07-31  ,
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#                     name                                           price_df  \
#  1338  Merfolk%20trident              Merfolk%20trident price  Merfolk%2...
#
#                                         item_df_training  \
#  1338              Merfolk%20trident price  Merfolk%2...
#
#                                               trimmed_df                regr  \
#  1338              Merfolk%20trident price  Merfolk%2...  LinearRegression()
#
#                                                   y_pred  \
#  1338  [866041.2462962962, 864647.6212962962, 849144....
#
#                                                   y_test  mean_squared_error  \
#  1338  date_obj
#  2020-04-16    863959.0
#  2020-04-17    ...        1.101948e+09
#
#        r2_score       roi                                          record_df  \
#  1338  0.905511  1.078465                 Prediction         Y     Y + 1 ...
#
#        perc_pred_increase    last_day
#  1338            0.050825  2020-07-31  ,
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#                       name                                           price_df  \
#  1564  Saradomin%20bracers              Saradomin%20bracers price  Saradom...
#
#                                         item_df_training  \
#  1564              Saradomin%20bracers price  Saradom...
#
#                                               trimmed_df                regr  \
#  1564              Saradomin%20bracers price  Saradom...  LinearRegression()
#
#                                                   y_pred  \
#  1564  [22729.80841980757, 21383.28107605757, 22101.7...
#
#                                                   y_test  mean_squared_error  \
#  1564  date_obj
#  2020-04-19    23252.0
#  2020-04-20    2...        4.710482e+06
#
#        r2_score       roi                                          record_df  \
#  1564   0.88471  1.084288                Prediction        Y    Y + 1    ...
#
#        perc_pred_increase    last_day
#  1564            0.050878  2020-07-31  ,
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#                        name                                           price_df  \
#  1903       Team%20cape%20x              Team%20cape%20x price  Team%20cape...
#  1924  Nail%20beast%20nails              Nail%20beast%20nails price  Nail%2...
#
#                                         item_df_training  \
#  1903              Team%20cape%20x price  Team%20cape...
#  1924              Nail%20beast%20nails price  Nail%2...
#
#                                               trimmed_df                regr  \
#  1903              Team%20cape%20x price  Team%20cape...  LinearRegression()
#  1924              Nail%20beast%20nails price  Nail%2...  LinearRegression()
#
#                                                   y_pred  \
#  1903  [1782499.5966748768, 1760957.5966748768, 17389...
#  1924  [10085.00688202527, 9659.27885468152, 9095.313...
#
#                                                   y_test  mean_squared_error  \
#  1903  date_obj
#  2020-04-16    1687752.0
#  2020-04-17   ...        4.070598e+09
#  1924  date_obj
#  2020-04-20     9497.0
#  2020-04-21     ...        1.701892e+06
#
#        r2_score       roi                                          record_df  \
#  1903  0.880521  1.214166                Prediction          Y      Y + 1...
#  1924  0.938476  1.592661                Prediction        Y    Y + 1    ...
#
#        perc_pred_increase    last_day
#  1903            0.036915  2020-07-31
#  1924            0.043952  2020-07-31  ,
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#                      name                                           price_df  \
#  2850  Mist%20battlestaff              Mist%20battlestaff price  Mist%20b...
#
#                                         item_df_training  \
#  2850              Mist%20battlestaff price  Mist%20b...
#
#                                               trimmed_df                regr  \
#  2850              Mist%20battlestaff price  Mist%20b...  LinearRegression()
#
#                                                   y_pred  \
#  2850  [93545.97978395062, 96343.47978395062, 99162.1...
#
#                                                   y_test  mean_squared_error  \
#  2850  date_obj
#  2020-04-16     99418.0
#  2020-04-17    ...        3.662679e+07
#
#        r2_score      roi                                          record_df  \
#  2850  0.871425  1.34245                 Prediction         Y     Y + 1 ...
#
#        perc_pred_increase    last_day
#  2850            0.040803  2020-07-31  ,
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#                   name                                           price_df  \
#  3020  Mole%20slippers              Mole%20slippers price  Mole%20slip...
#  3046       Oak%20logs              Oak%20logs price  Oak%20logs volum...
#
#                                         item_df_training  \
#  3020              Mole%20slippers price  Mole%20slip...
#  3046              Oak%20logs price  Oak%20logs volum...
#
#                                               trimmed_df                regr  \
#  3020              Mole%20slippers price  Mole%20slip...  LinearRegression()
#  3046              Oak%20logs price  Oak%20logs volum...  LinearRegression()
#
#                                                   y_pred  \
#  3020  [102341.72696834416, 105307.29728084416, 10637...
#  3046  [17.794087259736298, 17.302686911321317, 17.83...
#
#                                                   y_test  mean_squared_error  \
#  3020  date_obj
#  2020-05-10    101458.0
#  2020-05-11    ...        2.095884e+08
#  3046  date_obj
#  2020-02-20     18.0
#  2020-02-21     17...        9.906002e+01
#
#        r2_score       roi                                          record_df  \
#  3020  0.958967  1.702503                 Prediction         Y     Y + 1 ...
#  3046  0.949737  6.800254              Prediction      Y  Y + 1  Y - 1   ...
#
#        perc_pred_increase    last_day
#  3020            0.047278  2020-07-31
#  3046            0.044258  2020-07-31  ,
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#                             name  \
#  162  Black%20wizard%20hat%20(g)
#
#                                                price_df  \
#  162              Black%20wizard%20hat%20(g) price  ...
#
#                                        item_df_training  \
#  162              Black%20wizard%20hat%20(g) price  ...
#
#                                              trimmed_df                regr  \
#  162              Black%20wizard%20hat%20(g) price  ...  LinearRegression()
#
#                                                  y_pred  \
#  162  [391487.9598214286, 377538.5066964286, 385509....
#
#                                                  y_test  mean_squared_error  \
#  162  date_obj
#  2020-04-04    384204.0
#  2020-04-06    ...        1.042362e+08
#
#       r2_score       roi                                          record_df  \
#  162  0.964714  1.130223                 Prediction         Y     Y + 1 ...
#
#       perc_pred_increase    last_day
#  162            0.044321  2020-07-31  ,
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#                        name                                           price_df  \
#  403  Black%20shield%20(h1)              Black%20shield%20(h1) price  Black...
#
#                                        item_df_training  \
#  403              Black%20shield%20(h1) price  Black...
#
#                                              trimmed_df                regr  \
#  403              Black%20shield%20(h1) price  Black...  LinearRegression()
#
#                                                  y_pred  \
#  403  [2756.806000845773, 2730.172013419015, 2602.58...
#
#                                                  y_test  mean_squared_error  \
#  403  date_obj
#  2020-04-05    2526.0
#  2020-04-06    25...       136983.799702
#
#       r2_score       roi                                          record_df  \
#  403  0.936316  1.061357               Prediction       Y   Y + 1   Y - ...
#
#       perc_pred_increase    last_day
#  403            0.061413  2020-07-31  ,
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#                      name                                           price_df  \
#  937  White%20lily%20seed              White%20lily%20seed price  White%2...
#
#                                        item_df_training  \
#  937              White%20lily%20seed price  White%2...
#
#                                              trimmed_df                regr  \
#  937              White%20lily%20seed price  White%2...  LinearRegression()
#
#                                                  y_pred  \
#  937  [3939.4816059313325, 3761.1046528063325, 3443....
#
#                                                  y_test  mean_squared_error  \
#  937  date_obj
#  2020-04-22    3469.0
#  2020-04-23    34...        51839.678206
#
#       r2_score       roi                                          record_df  \
#  937  0.852554  1.218303               Prediction       Y   Y + 1   Y - ...
#
#       perc_pred_increase    last_day
#  937            0.030701  2020-07-31  ,
#                         name  \
#  1010  Maple%20longbow%20(u)
#
#                                                 price_df  \
#  1010              Maple%20longbow%20(u) price  Maple...
#
#                                         item_df_training  \
#  1010              Maple%20longbow%20(u) price  Maple...
#
#                                               trimmed_df                regr  \
#  1010              Maple%20longbow%20(u) price  Maple...  LinearRegression()
#
#                                                   y_pred  \
#  1010  [37.14832560946309, 37.872298555868504, 37.592...
#
#                                                   y_test  mean_squared_error  \
#  1010  date_obj
#  2020-02-20    36.0
#  2020-02-21    35.0...            7.415308
#
#        r2_score       roi                                          record_df  \
#  1010  0.956685  2.403655              Prediction     Y  Y + 1  Y - 1   v...
#
#        perc_pred_increase    last_day
#  1010            0.045528  2020-07-31  ,
#                  name                                           price_df  \
#  1159    Icy%20basalt              Icy%20basalt price  Icy%20basalt v...
#  1178  Ankou%20gloves              Ankou%20gloves price  Ankou%20glov...
#
#                                         item_df_training  \
#  1159              Icy%20basalt price  Icy%20basalt v...
#  1178              Ankou%20gloves price  Ankou%20glov...
#
#                                               trimmed_df                regr  \
#  1159              Icy%20basalt price  Icy%20basalt v...  LinearRegression()
#  1178              Ankou%20gloves price  Ankou%20glov...  LinearRegression()
#
#                                                   y_pred  \
#  1159  [1126.4144560558962, 1028.17171923949, 1067.33...
#  1178  [3136674.1088888887, 3204562.1088888887, 31773...
#
#                                                   y_test  mean_squared_error  \
#  1159  date_obj
#  2020-04-16    1020.0
#  2020-04-17     9...        5.190277e+03
#  1178  date_obj
#  2020-04-04    3123496.0
#  2020-04-05   ...        2.232945e+10
#
#        r2_score       roi                                          record_df  \
#  1159  0.858357  1.060704               Prediction       Y   Y + 1   Y - ...
#  1178  0.910772  1.493479                Prediction          Y      Y + 1...
#
#        perc_pred_increase    last_day
#  1159            0.089413  2020-07-31
#  1178            0.035729  2020-07-31  ,
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#                     name                                           price_df  \
#  1338  Merfolk%20trident              Merfolk%20trident price  Merfolk%2...
#
#                                         item_df_training  \
#  1338              Merfolk%20trident price  Merfolk%2...
#
#                                               trimmed_df                regr  \
#  1338              Merfolk%20trident price  Merfolk%2...  LinearRegression()
#
#                                                   y_pred  \
#  1338  [866041.2462962962, 864647.6212962962, 849144....
#
#                                                   y_test  mean_squared_error  \
#  1338  date_obj
#  2020-04-16    863959.0
#  2020-04-17    ...        1.101948e+09
#
#        r2_score       roi                                          record_df  \
#  1338  0.905511  1.078465                 Prediction         Y     Y + 1 ...
#
#        perc_pred_increase    last_day
#  1338            0.050825  2020-07-31  ,
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#                       name                                           price_df  \
#  1564  Saradomin%20bracers              Saradomin%20bracers price  Saradom...
#
#                                         item_df_training  \
#  1564              Saradomin%20bracers price  Saradom...
#
#                                               trimmed_df                regr  \
#  1564              Saradomin%20bracers price  Saradom...  LinearRegression()
#
#                                                   y_pred  \
#  1564  [22729.80841980757, 21383.28107605757, 22101.7...
#
#                                                   y_test  mean_squared_error  \
#  1564  date_obj
#  2020-04-19    23252.0
#  2020-04-20    2...        4.710482e+06
#
#        r2_score       roi                                          record_df  \
#  1564   0.88471  1.084288                Prediction        Y    Y + 1    ...
#
#        perc_pred_increase    last_day
#  1564            0.050878  2020-07-31  ,
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#                        name                                           price_df  \
#  1903       Team%20cape%20x              Team%20cape%20x price  Team%20cape...
#  1924  Nail%20beast%20nails              Nail%20beast%20nails price  Nail%2...
#
#                                         item_df_training  \
#  1903              Team%20cape%20x price  Team%20cape...
#  1924              Nail%20beast%20nails price  Nail%2...
#
#                                               trimmed_df                regr  \
#  1903              Team%20cape%20x price  Team%20cape...  LinearRegression()
#  1924              Nail%20beast%20nails price  Nail%2...  LinearRegression()
#
#                                                   y_pred  \
#  1903  [1782499.5966748768, 1760957.5966748768, 17389...
#  1924  [10085.00688202527, 9659.27885468152, 9095.313...
#
#                                                   y_test  mean_squared_error  \
#  1903  date_obj
#  2020-04-16    1687752.0
#  2020-04-17   ...        4.070598e+09
#  1924  date_obj
#  2020-04-20     9497.0
#  2020-04-21     ...        1.701892e+06
#
#        r2_score       roi                                          record_df  \
#  1903  0.880521  1.214166                Prediction          Y      Y + 1...
#  1924  0.938476  1.592661                Prediction        Y    Y + 1    ...
#
#        perc_pred_increase    last_day
#  1903            0.036915  2020-07-31
#  1924            0.043952  2020-07-31  ,
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#                      name                                           price_df  \
#  2850  Mist%20battlestaff              Mist%20battlestaff price  Mist%20b...
#
#                                         item_df_training  \
#  2850              Mist%20battlestaff price  Mist%20b...
#
#                                               trimmed_df                regr  \
#  2850              Mist%20battlestaff price  Mist%20b...  LinearRegression()
#
#                                                   y_pred  \
#  2850  [93545.97978395062, 96343.47978395062, 99162.1...
#
#                                                   y_test  mean_squared_error  \
#  2850  date_obj
#  2020-04-16     99418.0
#  2020-04-17    ...        3.662679e+07
#
#        r2_score      roi                                          record_df  \
#  2850  0.871425  1.34245                 Prediction         Y     Y + 1 ...
#
#        perc_pred_increase    last_day
#  2850            0.040803  2020-07-31  ,
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: [],
#                   name                                           price_df  \
#  3020  Mole%20slippers              Mole%20slippers price  Mole%20slip...
#  3046       Oak%20logs              Oak%20logs price  Oak%20logs volum...
#
#                                         item_df_training  \
#  3020              Mole%20slippers price  Mole%20slip...
#  3046              Oak%20logs price  Oak%20logs volum...
#
#                                               trimmed_df                regr  \
#  3020              Mole%20slippers price  Mole%20slip...  LinearRegression()
#  3046              Oak%20logs price  Oak%20logs volum...  LinearRegression()
#
#                                                   y_pred  \
#  3020  [102341.72696834416, 105307.29728084416, 10637...
#  3046  [17.794087259736298, 17.302686911321317, 17.83...
#
#                                                   y_test  mean_squared_error  \
#  3020  date_obj
#  2020-05-10    101458.0
#  2020-05-11    ...        2.095884e+08
#  3046  date_obj
#  2020-02-20     18.0
#  2020-02-21     17...        9.906002e+01
#
#        r2_score       roi                                          record_df  \
#  3020  0.958967  1.702503                 Prediction         Y     Y + 1 ...
#  3046  0.949737  6.800254              Prediction      Y  Y + 1  Y - 1   ...
#
#        perc_pred_increase    last_day
#  3020            0.047278  2020-07-31
#  3046            0.044258  2020-07-31  ,
#  Empty DataFrame
#  Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day]
#  Index: []]

# %%
trading_df = pd.concat(df_list, axis=0).sort_values(by='perc_pred_increase', ascending=False)
trading_df.columns
# Out:
# Index(['name', 'price_df', 'item_df_training', 'trimmed_df', 'regr', 'y_pred',
#        'y_test', 'mean_squared_error', 'r2_score', 'roi', 'record_df',
#        'perc_pred_increase', 'last_day'],
#       dtype='object')

# %%
trading_df.loc[:,['name', 'mean_squared_error', 'r2_score', 'roi', 'perc_pred_increase','last_day']]
# Out:
#                             name  mean_squared_error  r2_score       roi  \
# 1159                Icy%20basalt        5.190277e+03  0.858357  1.060704
# 1159                Icy%20basalt        5.190277e+03  0.858357  1.060704
# 403        Black%20shield%20(h1)        1.369838e+05  0.936316  1.061357
# 403        Black%20shield%20(h1)        1.369838e+05  0.936316  1.061357
# 1564         Saradomin%20bracers        4.710482e+06  0.884710  1.084288
# 1564         Saradomin%20bracers        4.710482e+06  0.884710  1.084288
# 1338           Merfolk%20trident        1.101948e+09  0.905511  1.078465
# 1338           Merfolk%20trident        1.101948e+09  0.905511  1.078465
# 3020             Mole%20slippers        2.095884e+08  0.958967  1.702503
# 3020             Mole%20slippers        2.095884e+08  0.958967  1.702503
# 1010       Maple%20longbow%20(u)        7.415308e+00  0.956685  2.403655
# 1010       Maple%20longbow%20(u)        7.415308e+00  0.956685  2.403655
# 162   Black%20wizard%20hat%20(g)        1.042362e+08  0.964714  1.130223
# 162   Black%20wizard%20hat%20(g)        1.042362e+08  0.964714  1.130223
# 3046                  Oak%20logs        9.906002e+01  0.949737  6.800254
# 3046                  Oak%20logs        9.906002e+01  0.949737  6.800254
# 1924        Nail%20beast%20nails        1.701892e+06  0.938476  1.592661
# 1924        Nail%20beast%20nails        1.701892e+06  0.938476  1.592661
# 2850          Mist%20battlestaff        3.662679e+07  0.871425  1.342450
# 2850          Mist%20battlestaff        3.662679e+07  0.871425  1.342450
# 1903             Team%20cape%20x        4.070598e+09  0.880521  1.214166
# 1903             Team%20cape%20x        4.070598e+09  0.880521  1.214166
# 1178              Ankou%20gloves        2.232945e+10  0.910772  1.493479
# 1178              Ankou%20gloves        2.232945e+10  0.910772  1.493479
# 937          White%20lily%20seed        5.183968e+04  0.852554  1.218303
# 937          White%20lily%20seed        5.183968e+04  0.852554  1.218303
#
#       perc_pred_increase    last_day
# 1159            0.089413  2020-07-31
# 1159            0.089413  2020-07-31
# 403             0.061413  2020-07-31
# 403             0.061413  2020-07-31
# 1564            0.050878  2020-07-31
# 1564            0.050878  2020-07-31
# 1338            0.050825  2020-07-31
# 1338            0.050825  2020-07-31
# 3020            0.047278  2020-07-31
# 3020            0.047278  2020-07-31
# 1010            0.045528  2020-07-31
# 1010            0.045528  2020-07-31
# 162             0.044321  2020-07-31
# 162             0.044321  2020-07-31
# 3046            0.044258  2020-07-31
# 3046            0.044258  2020-07-31
# 1924            0.043952  2020-07-31
# 1924            0.043952  2020-07-31
# 2850            0.040803  2020-07-31
# 2850            0.040803  2020-07-31
# 1903            0.036915  2020-07-31
# 1903            0.036915  2020-07-31
# 1178            0.035729  2020-07-31
# 1178            0.035729  2020-07-31
# 937             0.030701  2020-07-31
# 937             0.030701  2020-07-31

# %%
currently_buying = []
currently_buying = trading_df['name'][0:4]

bought.merge(currently_buying)
bought.to_csv('data/bought', index=False)

# %%
pd.read_csv('data/bought')
# Out:
#                     name
# 0           Icy%20basalt
# 1  Black%20shield%20(h1)
# 2    Saradomin%20bracers
# 3      Merfolk%20trident
# 4   Mithril%20kiteshield

# %%
trading_dfing_dfing_dfing_df.loc[:,['name', 'mean_squared_error', 'r2_score', 'roi', 'perc_pred_increase','last_day']].to_csv('data/trading_8.2.csv')

# %% [markdown]
# # fastai tabular data

# %%
procs = [Normalize]

# %%
valid_idx = range(int(len(df)*.8), len(df)-60)

# %%
dep_var = 'Y'

# %%
path = Path(f'./data/wiki_urls/{item_name}')

# %%
trimmed_df['date_obj'] = trimmed_df.index

# %%
trimmed_df['date_obj'] = trimmed_df['date_obj'].apply(lambda x: pd.to_datetime(x))

# %%
time_trimmed_df = trimmed_df.loc[trimmed_df['date_obj'] > pd.to_datetime('2018-05-01')]

# %%
time_trimmed_df[item_name].plot()

# %%
time_trimmed_df = time_trimmed_df.drop(columns=['date_obj'], axis=1)

# %%
trimmed_df = time_trimmed_df

# %%
df = trimmed_df

# %%
df

# %%
data = TabularDataBunch.from_df(path, df, dep_var, valid_idx=valid_idx, procs=procs, cat_names=[])

# %%
learn = tabular_learner(data, layers=[500,100], emb_szs={'native-country': 10}, metrics=mean_squared_error)

# %%
data.show_batch()

# %%
learn.save('stage-0')

# %%
learn.lr_find(end_lr=1e3)

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(5, max_lr=1e-2)

# %%
learn.fit_one_cycle(5, max_lr=1e-2)

# %%
learn.show_results(ds_type=DatasetType.Train)

# %%
learn.save('stage-1')

# %%
learn = learn.load('stage-1')

# %%
learn.lr_find()

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(5, 3e-5)

# %%
learn.show_results(ds_type=DatasetType.Train)

# %%
learn.save('stage-2')

# %%
learn.lr_find()

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(5, 3e-6)

# %%
learn.save('stage-3')

# %%
learn.show_results(ds_type=DatasetType.Train)

# %%
learn.lr_find()
learn.recorder.plot()

# %%
learn.fit_one_cycle(5, 3e-4)

# %%
learn.save('stage-4')

# %%
learn.lr_find(end_lr=1e2)
learn.recorder.plot()

# %%
learn.show_results(ds_type=DatasetType.Train)

# %%
learn.fit_one_cycle(10, 1e-4)

# %%
learn = learn.load('stage-4')

# %%
learn.show_results(ds_type=DatasetType.Train)

# %% [markdown]
# # Plot results

# %%
int(learn.predict(df.iloc[0])[1])

# %%
learn.predict(df.iloc[0])

# %%
plot_x = [float(learn.predict(df.iloc[i])[1]) for i in range(len(df))]

# %%
plot_y = df['Y']

# %%
plot_y

# %%
plot_x

# %%
plot_df = pd.DataFrame(plot_y)

# %%
plot_df['x'] = plot_x

# %%
plot_df.head()

# %%
plot_df.plot()

# %%
plt.plot(plot_x)

# %%
plt.plot(plot_y)

# %%
plt.plot(range(len(plot_x)),np.array([plot_x,plot_y]).T)

# %%
len(plot_x)

# %%
plt.plot(range(len(plot_x[len(plot_x)-60:])), np.array([plot_x[len(plot_x)-60:], plot_y[len(plot_y)-60:]]).T)
plt.legend()

# %%
plt.plot(plot_x[len(plot_x)-60:])

# %%
len(plot_x)

# %%
plt.plot(plot_y[len(plot_y)-60:])

# %%
x_series = pd.Series(plot_x, name='Predict')

# %%
type(x_series)

# %%
type(plot_y)

# %%
y_series = plot_y.reindex(x_series.index)

# %%
y_series

# %%
x_series

# %%
pd.concat([y_series, x_series],  axis=1).iloc[1705-60:].plot()

# %%
learn.drop

# %%
learn.save('stage-final')
learn.export()

# %% [markdown]
# # Load in the full data (recent rows will have been dropped because Ys were N/A)

# %%
prediction_df = item_df_training

# %%
prediction_df['constant'] = time_trimmed_df['Y'].mean() *scaling_factor

# %%
prediction_df.columns

# %%
prediction_df = prediction_df.fillna(method='ffill').fillna(method='bfill').fillna(0)

# %%
predict_data = TabularDataBunch.from_df(path, prediction_df, dep_var, valid_idx=valid_idx, procs=procs, cat_names=[])

# %%
predict_learn = tabular_learner(data, layers=[500,100], emb_szs={'native-country': 10}, metrics=mean_squared_error)

# %%
predict_learn =predict_learn.load('stage-final')

# %%
predict_learn.show_results(ds_type=DatasetType.Train)

# %%
predict_learn.predict(prediction_df.iloc[0])

# %%
predict_learn.predict(prediction_df.iloc[100])

# %%
prediction_df

# %%
predictions = [float(predict_learn.predict(prediction_df.iloc[i])[1]) for i in range(len(prediction_df))]

# %%
predictions

# %%
prediction_df.tail()

# %%
prediction_df['predictions'] = predictions

# %%
prediction_df['predictions'].tail(30)

# %%
prediction_df

# %% [markdown]
# ####
