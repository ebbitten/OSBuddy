# %% [markdown]
# # Libraries + Torch check

# %%
import pandas as pd
import requests
import json
from pathlib import Path
import re
from datetime import date
import time
import os
from fastai.tabular import *
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model
import sklearn.metrics
from sklearn.model_selection import train_test_split
import math

# %%
import torch

# %%
torch.cuda.device(0)

# %%
torch.cuda.get_device_name(0)
# Out:
# 'GeForce RTX 2080'

# %% [markdown]
# # Data Retrieval

# %%
cleaned_item_names = [name[:-10] for name in list(os.walk(r'data/wiki_prices'))[0][2]]

# %%
cleaned_item_names[0:5]
# Out:
# ['Potato%20seed', 'Tin%20ore', 'Gout%20tuber', 'Bronze%20bolts', 'Gold%20seal']

# %%
#pd.Series(cleaned_item_names).to_csv('./data/cleaned_item_names', index=False, header=False)

# %%
len(cleaned_item_names)
# Out:
# 3147

# %%
# cleaned_item_names

# %%
def get_item_df(item_name, sleppy_time=1):
    base_url = r"https://oldschool.runescape.wiki/api.php?action=query&prop=revisions&rvprop=content&format=json&titles=Module%3AExchange%2F"
    postfix_url = r"%2FData"
    full_url = f'{base_url}{item_name}{postfix_url}'
    resp = requests.get(full_url)
    jsond = resp.json()
    try:
        regex_text = jsond['query']['pages'][next(iter(jsond['query']['pages'].keys()))]['revisions'][0]['*']
        #get all of the ones that have volume as well as price
        m = re.findall(r'[\d]+:[\d]+:[\d]+', regex_text)
        item_df = pd.DataFrame()
        item_df['dt'] = [int(string.split(':')[0]) for string in m]
        item_df[f'{item_name} price'] = [int(string.split(':')[1]) for string in m]
        item_df[f'{item_name} volume'] = [int(string.split(':')[2]) for string in m]
        item_df['date_obj'] = item_df['dt'].apply(lambda x: date.fromtimestamp(x))
        #take the ones that just have price so we can get the most recent price as well
        n = re.findall(r'[\d]+:[\d]+', regex_text)
        last_time = date.fromtimestamp(int(n[-1].split(':')[0]))
        last_price = int(n[-1].split(':')[1])
        item_df.loc[-1, 'date_obj'] = last_time
        item_df.loc[-1, f'{item_name} price'] = last_price
        item_df = item_df.fillna(method='ffill')
        item_df.set_index('date_obj', inplace=True)
        item_df = item_df.drop('dt', axis=1)
        return item_df
    except:
        pass

# %%
def retrieve_dfs(xslice = True):
    if xslice:
        item_dfs = [get_item_df(item_name,1) for item_name in cleaned_item_names[40:45]]
    else:
        item_dfs = [get_item_df(item_name,1) for item_name in cleaned_item_names]
    return item_dfs

# %%
item_dfs = retrieve_dfs(False)

# %%
item_dfs
# Out:
# [            Potato%20seed price  Potato%20seed volume
#  date_obj
#  2018-12-07                  1.0              836492.0
#  2018-12-09                  1.0              686407.0
#  2018-12-10                  1.0              401364.0
#  2018-12-11                  1.0              593491.0
#  2018-12-12                  1.0              674040.0
#  ...                         ...                   ...
#  2020-08-02                  1.0             1062819.0
#  2020-08-03                  1.0              973729.0
#  2020-08-04                  1.0              931344.0
#  2020-08-05                  1.0              675435.0
#  2020-08-06                  1.0              675435.0
#
#  [606 rows x 2 columns],
#              Tin%20ore price  Tin%20ore volume
#  date_obj
#  2018-12-09             52.0          776948.0
#  2018-12-10             51.0          330517.0
#  2018-12-11             50.0          604209.0
#  2018-12-12             49.0          799359.0
#  2018-12-13             48.0          480364.0
#  ...                     ...               ...
#  2020-08-02             66.0          173327.0
#  2020-08-03             67.0          177837.0
#  2020-08-04             65.0          194196.0
#  2020-08-05             65.0          126555.0
#  2020-08-06             61.0          126555.0
#
#  [606 rows x 2 columns],
#              Gout%20tuber price  Gout%20tuber volume
#  date_obj
#  2018-12-25            702402.0                139.0
#  2018-12-26            693108.0                295.0
#  2018-12-27            697444.0                104.0
#  2018-12-28            697444.0                325.0
#  2018-12-29            706080.0                153.0
#  ...                        ...                  ...
#  2020-08-02            689217.0                230.0
#  2020-08-03            697643.0                159.0
#  2020-08-04            690426.0                192.0
#  2020-08-05            668831.0                142.0
#  2020-08-06            654225.0                142.0
#
#  [584 rows x 2 columns],
#              Bronze%20bolts price  Bronze%20bolts volume
#  date_obj
#  2018-09-24                   4.0              1124040.0
#  2018-09-25                   4.0               457615.0
#  2018-09-26                   4.0              1255242.0
#  2018-09-27                   4.0              2187108.0
#  2018-09-28                   4.0              1213733.0
#  ...                          ...                    ...
#  2020-08-02                   2.0              2931965.0
#  2020-08-03                   2.0              1891902.0
#  2020-08-04                   2.0              2113140.0
#  2020-08-05                   2.0              2322585.0
#  2020-08-06                   2.0              2322585.0
#
#  [662 rows x 2 columns],
#              Gold%20seal price  Gold%20seal volume
#  date_obj
#  2018-12-09              746.0             20725.0
#  2018-12-11              746.0             13510.0
#  2018-12-12              748.0             21800.0
#  2018-12-13              745.0             10453.0
#  2018-12-14              745.0             19242.0
#  ...                       ...                 ...
#  2020-08-02              764.0             27488.0
#  2020-08-03              757.0             21288.0
#  2020-08-04              761.0             26256.0
#  2020-08-05              773.0             16371.0
#  2020-08-06              773.0             16371.0
#
#  [600 rows x 2 columns],
#              Avantoe%20potion%20(unf) price  Avantoe%20potion%20(unf) volume
#  date_obj
#  2018-09-24                          2254.0                         242043.0
#  2018-09-25                          2254.0                         140336.0
#  2018-09-26                          2279.0                         395726.0
#  2018-09-27                          2259.0                         713704.0
#  2018-09-28                          2346.0                         496459.0
#  ...                                    ...                              ...
#  2020-08-02                          1949.0                        1135277.0
#  2020-08-03                          1997.0                         781467.0
#  2020-08-04                          1966.0                         853357.0
#  2020-08-05                          1966.0                         650603.0
#  2020-08-06                          2013.0                         650603.0
#
#  [655 rows x 2 columns],
#              Mithril%20arrow price  Mithril%20arrow volume
#  date_obj
#  2018-02-18                   34.0                    15.0
#  2018-02-19                   34.0                    16.0
#  2018-02-20                   34.0                    16.0
#  2018-02-21                   34.0                    17.0
#  2018-02-22                   33.0                    18.0
#  ...                           ...                     ...
#  2020-08-02                   17.0               6085853.0
#  2020-08-03                   17.0               5283020.0
#  2020-08-04                   17.0               5871827.0
#  2020-08-05                   17.0               4055348.0
#  2020-08-06                   17.0               4055348.0
#
#  [886 rows x 2 columns],
#              Royal%20gown%20bottom price  Royal%20gown%20bottom volume
#  date_obj
#  2018-12-24                      37744.0                          80.0
#  2018-12-25                      37744.0                          66.0
#  2018-12-26                      38129.0                         148.0
#  2018-12-27                      39270.0                          75.0
#  2018-12-28                      39270.0                         184.0
#  ...                                 ...                           ...
#  2020-08-02                      25727.0                          64.0
#  2020-08-03                      25727.0                          50.0
#  2020-08-04                      25543.0                          65.0
#  2020-08-05                      25543.0                          30.0
#  2020-08-06                      25644.0                          30.0
#
#  [590 rows x 2 columns],
#              Grimy%20marrentill price  Grimy%20marrentill volume
#  date_obj
#  2018-12-09                      19.0                   589958.0
#  2018-12-10                      18.0                   382221.0
#  2018-12-11                      17.0                   632677.0
#  2018-12-13                      16.0                   712279.0
#  2018-12-14                      15.0                   787149.0
#  ...                              ...                        ...
#  2020-08-02                      15.0                   398466.0
#  2020-08-03                      15.0                   329695.0
#  2020-08-04                      15.0                   358712.0
#  2020-08-05                      15.0                   304992.0
#  2020-08-06                      15.0                   304992.0
#
#  [601 rows x 2 columns],
#              Steel%20longsword price  Steel%20longsword volume
#  date_obj
#  2018-12-09                    121.0                   13193.0
#  2018-12-10                    124.0                    7451.0
#  2018-12-11                    126.0                   10300.0
#  2018-12-12                    128.0                   12308.0
#  2018-12-13                    128.0                   10165.0
#  ...                             ...                       ...
#  2020-08-02                    144.0                    6067.0
#  2020-08-03                    147.0                    7292.0
#  2020-08-04                    142.0                    5858.0
#  2020-08-05                    149.0                    6353.0
#  2020-08-06                    147.0                    6353.0
#
#  [606 rows x 2 columns],
#              Dwellberries price  Dwellberries volume
#  date_obj
#  2018-12-09               139.0               3417.0
#  2018-12-10               139.0               2794.0
#  2018-12-11               138.0               2753.0
#  2018-12-12               140.0               3651.0
#  2018-12-13               137.0               2668.0
#  ...                        ...                  ...
#  2020-08-02                45.0               1727.0
#  2020-08-03                45.0               2107.0
#  2020-08-04                45.0               2234.0
#  2020-08-05                45.0               1467.0
#  2020-08-06                45.0               1467.0
#
#  [597 rows x 2 columns],
#              Smoke%20rune price  Smoke%20rune volume
#  date_obj
#  2018-12-09                34.0            1258996.0
#  2018-12-10                35.0             748367.0
#  2018-12-11                35.0            1069410.0
#  2018-12-12                37.0            1294995.0
#  2018-12-13                37.0             930366.0
#  ...                        ...                  ...
#  2020-08-02                79.0            2155915.0
#  2020-08-03                81.0            1660853.0
#  2020-08-04                80.0            2013416.0
#  2020-08-05                81.0            1544272.0
#  2020-08-06                81.0            1544272.0
#
#  [605 rows x 2 columns],
#              3rd%20age%20druidic%20robe%20bottoms price  \
#  date_obj
#  2019-04-11                                1.500000e+08
#  2019-04-12                                1.500000e+08
#  2019-04-13                                1.556280e+08
#  2019-04-14                                1.556280e+08
#  2019-04-15                                5.000000e+08
#  ...                                                ...
#  2020-08-02                                1.026419e+09
#  2020-08-03                                1.026419e+09
#  2020-08-04                                1.026419e+09
#  2020-08-05                                1.026419e+09
#  2020-08-06                                1.026419e+09
#
#              3rd%20age%20druidic%20robe%20bottoms volume
#  date_obj
#  2019-04-11                                          1.0
#  2019-04-12                                          0.0
#  2019-04-13                                          0.0
#  2019-04-14                                          0.0
#  2019-04-15                                          0.0
#  ...                                                 ...
#  2020-08-02                                          9.0
#  2020-08-03                                          5.0
#  2020-08-04                                         12.0
#  2020-08-05                                          8.0
#  2020-08-06                                          8.0
#
#  [463 rows x 2 columns],
#              Sea%20turtle price  Sea%20turtle volume
#  date_obj
#  2018-12-24              1025.0              17278.0
#  2018-12-25               995.0              15858.0
#  2018-12-26               995.0              26122.0
#  2018-12-27              1018.0               4506.0
#  2018-12-28              1018.0              24328.0
#  ...                        ...                  ...
#  2020-08-02               952.0              57231.0
#  2020-08-03               952.0              69896.0
#  2020-08-04               975.0              41870.0
#  2020-08-05               975.0              40048.0
#  2020-08-06               976.0              40048.0
#
#  [590 rows x 2 columns],
#              Fishing%20rod price  Fishing%20rod volume
#  date_obj
#  2018-12-09                105.0                6755.0
#  2018-12-10                101.0                3464.0
#  2018-12-11                101.0                6253.0
#  2018-12-12                103.0                6323.0
#  2018-12-13                106.0                5164.0
#  ...                         ...                   ...
#  2020-08-02                111.0                1721.0
#  2020-08-03                114.0                1251.0
#  2020-08-04                115.0                1322.0
#  2020-08-05                113.0                 898.0
#  2020-08-06                112.0                 898.0
#
#  [601 rows x 2 columns],
#              Papaya%20tree%20seed price  Papaya%20tree%20seed volume
#  date_obj
#  2018-12-24                      6770.0                      37996.0
#  2018-12-25                      6819.0                      36297.0
#  2018-12-26                      6836.0                      89478.0
#  2018-12-27                      6851.0                      33995.0
#  2018-12-28                      6727.0                      94413.0
#  ...                                ...                          ...
#  2020-08-02                      4452.0                      43049.0
#  2020-08-03                      4476.0                      31775.0
#  2020-08-04                      4487.0                      35194.0
#  2020-08-05                      4534.0                      28819.0
#  2020-08-06                      4576.0                      28819.0
#
#  [590 rows x 2 columns],
#              Blue%20skirt price  Blue%20skirt volume
#  date_obj
#  2018-09-24                88.0               1400.0
#  2018-09-25                88.0                481.0
#  2018-09-26                85.0               1463.0
#  2018-09-27                85.0               2336.0
#  2018-09-28                84.0               2178.0
#  ...                        ...                  ...
#  2020-08-02                55.0               1260.0
#  2020-08-03                55.0               1325.0
#  2020-08-04                52.0               1083.0
#  2020-08-05                49.0                683.0
#  2020-08-06                49.0                683.0
#
#  [661 rows x 2 columns],
#              Efh%20salt price  Efh%20salt volume
#  date_obj
#  2018-12-07              85.0           159585.0
#  2018-12-09              92.0           202264.0
#  2018-12-10              96.0           106177.0
#  2018-12-11              96.0            71006.0
#  2018-12-12             101.0           129929.0
#  ...                      ...                ...
#  2020-08-02              37.0           381052.0
#  2020-08-03              38.0           287662.0
#  2020-08-04              39.0           270470.0
#  2020-08-05              41.0           252282.0
#  2020-08-06              43.0           252282.0
#
#  [602 rows x 2 columns],
#              Inquisitor's%20armour%20set price  \
#  date_obj
#  2020-02-06                       4.631829e+07
#  2020-02-07                       4.825211e+07
#  2020-02-08                       5.027724e+07
#  2020-02-09                       5.219384e+07
#  2020-02-10                       5.424295e+07
#  ...                                       ...
#  2020-08-02                       1.164796e+09
#  2020-08-03                       1.189474e+09
#  2020-08-04                       1.189474e+09
#  2020-08-05                       1.216053e+09
#  2020-08-06                       1.216053e+09
#
#              Inquisitor's%20armour%20set volume
#  date_obj
#  2020-02-06                                 0.0
#  2020-02-07                                 0.0
#  2020-02-08                                 0.0
#  2020-02-09                                 0.0
#  2020-02-10                                 0.0
#  ...                                        ...
#  2020-08-02                                33.0
#  2020-08-03                                33.0
#  2020-08-04                                34.0
#  2020-08-05                                40.0
#  2020-08-06                                40.0
#
#  [182 rows x 2 columns],
#              Mithril%20platebody%20(t) price  Mithril%20platebody%20(t) volume
#  date_obj
#  2018-12-24                          10170.0                             144.0
#  2018-12-25                           9964.0                             182.0
#  2018-12-26                           9819.0                             447.0
#  2018-12-27                           9630.0                             155.0
#  2018-12-28                           9401.0                             457.0
#  ...                                     ...                               ...
#  2020-08-02                           4702.0                             149.0
#  2020-08-03                           4938.0                              98.0
#  2020-08-04                           5160.0                             116.0
#  2020-08-05                           5418.0                             113.0
#  2020-08-06                           5580.0                             113.0
#
#  [589 rows x 2 columns],
#              Burnt%20page price  Burnt%20page volume
#  date_obj
#  2018-09-24              5900.0              97720.0
#  2018-09-25              5925.0              41240.0
#  2018-09-26              5915.0             101357.0
#  2018-09-27              5939.0             183634.0
#  2018-09-28              5972.0             149892.0
#  ...                        ...                  ...
#  2020-08-02              2950.0             526224.0
#  2020-08-03              2915.0             406980.0
#  2020-08-04              2885.0             449511.0
#  2020-08-05              2833.0             354510.0
#  2020-08-06              2852.0             354510.0
#
#  [665 rows x 2 columns],
#              Mystic%20dust%20staff price  Mystic%20dust%20staff volume
#  date_obj
#  2018-12-07                     124778.0                         508.0
#  2018-12-09                     118333.0                         383.0
#  2018-12-10                     112615.0                         217.0
#  2018-12-11                     109692.0                         298.0
#  2018-12-12                     105263.0                         344.0
#  ...                                 ...                           ...
#  2020-08-02                      59629.0                         212.0
#  2020-08-03                      59893.0                         209.0
#  2020-08-04                      59864.0                         189.0
#  2020-08-05                      61052.0                         166.0
#  2020-08-06                      60443.0                         166.0
#
#  [606 rows x 2 columns],
#              Skewer price  Skewer volume
#  date_obj
#  2018-12-24        2820.0            4.0
#  2018-12-25        2820.0            5.0
#  2018-12-26        2820.0            9.0
#  2018-12-27        2820.0            4.0
#  2018-12-28        2820.0            7.0
#  ...                  ...            ...
#  2020-08-02        2500.0           13.0
#  2020-08-03        2500.0            0.0
#  2020-08-04        2500.0            3.0
#  2020-08-05        2500.0            4.0
#  2020-08-06        2500.0            4.0
#
#  [590 rows x 2 columns],
#              Gilded%20spade price  Gilded%20spade volume
#  date_obj
#  2019-04-11              520257.0                   68.0
#  2019-04-12              543431.0                   36.0
#  2019-04-13              566204.0                    9.0
#  2019-04-14              593053.0                   17.0
#  2019-04-15            27000000.0                   11.0
#  ...                          ...                    ...
#  2020-08-02             4526879.0                   57.0
#  2020-08-03             4526879.0                   39.0
#  2020-08-04             4526879.0                   78.0
#  2020-08-05             4342595.0                   44.0
#  2020-08-06             4342595.0                   44.0
#
#  [485 rows x 2 columns],
#              Mystic%20boots%20(dark) price  Mystic%20boots%20(dark) volume
#  date_obj
#  2018-12-24                        93783.0                           665.0
#  2018-12-25                        95339.0                           830.0
#  2018-12-26                        93918.0                          1684.0
#  2018-12-27                        92379.0                           622.0
#  2018-12-28                        91610.0                          1745.0
#  ...                                   ...                             ...
#  2020-08-02                        94612.0                           518.0
#  2020-08-03                        93975.0                           398.0
#  2020-08-04                        92000.0                           543.0
#  2020-08-05                        91863.0                           403.0
#  2020-08-06                        91863.0                           403.0
#
#  [588 rows x 2 columns],
#              Samurai%20shirt price  Samurai%20shirt volume
#  date_obj
#  2018-12-07               469554.0                   275.0
#  2018-12-09               479147.0                   233.0
#  2018-12-10               489030.0                   122.0
#  2018-12-11               489030.0                   165.0
#  2018-12-12               496340.0                   175.0
#  ...                           ...                     ...
#  2020-08-02               199317.0                    99.0
#  2020-08-03               199096.0                   105.0
#  2020-08-04               199096.0                    96.0
#  2020-08-05               197629.0                    74.0
#  2020-08-06               197629.0                    74.0
#
#  [607 rows x 2 columns],
#              Mummy's%20legs price  Mummy's%20legs volume
#  date_obj
#  2018-12-07             1008144.0                   27.0
#  2018-12-09             1008144.0                   23.0
#  2018-12-10             1052970.0                    9.0
#  2018-12-11             1052970.0                    7.0
#  2018-12-13             1052970.0                   14.0
#  ...                          ...                    ...
#  2020-08-02              514472.0                   17.0
#  2020-08-03              514472.0                    7.0
#  2020-08-04              539460.0                   11.0
#  2020-08-05              539460.0                   17.0
#  2020-08-06              539460.0                   17.0
#
#  [605 rows x 2 columns],
#              Grimy%20irit%20leaf price  Grimy%20irit%20leaf volume
#  date_obj
#  2018-12-24                      920.0                    423002.0
#  2018-12-25                      907.0                    378073.0
#  2018-12-26                      908.0                    996910.0
#  2018-12-27                      904.0                    462341.0
#  2018-12-28                      902.0                   1043628.0
#  ...                               ...                         ...
#  2020-08-02                      698.0                    933917.0
#  2020-08-03                      712.0                    678707.0
#  2020-08-04                      717.0                    708437.0
#  2020-08-05                      705.0                    573541.0
#  2020-08-06                      712.0                    573541.0
#
#  [589 rows x 2 columns],
#              Ring%20of%20life price  Ring%20of%20life volume
#  date_obj
#  2018-12-24                  1949.0                   8175.0
#  2018-12-25                  1937.0                  14181.0
#  2018-12-26                  1889.0                  30897.0
#  2018-12-27                  1907.0                  10124.0
#  2018-12-28                  1918.0                  26196.0
#  ...                            ...                      ...
#  2020-08-02                  1898.0                  31959.0
#  2020-08-03                  1881.0                  17179.0
#  2020-08-04                  1876.0                  30733.0
#  2020-08-05                  1879.0                  28240.0
#  2020-08-06                  1891.0                  28240.0
#
#  [591 rows x 2 columns],
#              Berserker%20helm price  Berserker%20helm volume
#  date_obj
#  2018-09-24                 56044.0                   1810.0
#  2018-09-25                 57996.0                    818.0
#  2018-09-26                 57745.0                   2421.0
#  2018-09-27                 57284.0                   4308.0
#  2018-09-28                 56230.0                   2846.0
#  ...                            ...                      ...
#  2020-08-02                 41299.0                   3071.0
#  2020-08-03                 41114.0                   2315.0
#  2020-08-04                 42010.0                   2825.0
#  2020-08-05                 42117.0                   2244.0
#  2020-08-06                 42171.0                   2244.0
#
#  [656 rows x 2 columns],
#              Adamant%20hasta price  Adamant%20hasta volume
#  date_obj
#  2018-09-24                 1028.0                    59.0
#  2018-09-25                 1028.0                     4.0
#  2018-09-26                 1041.0                    43.0
#  2018-09-27                 1041.0                    88.0
#  2018-09-28                 1041.0                    82.0
#  ...                           ...                     ...
#  2020-08-02                  912.0                   170.0
#  2020-08-03                  912.0                    71.0
#  2020-08-04                  884.0                   146.0
#  2020-08-05                  884.0                    91.0
#  2020-08-06                  884.0                    91.0
#
#  [658 rows x 2 columns],
#              Mithril%20trimmed%20set%20(sk) price  \
#  date_obj
#  2018-12-24                               36972.0
#  2018-12-25                               36972.0
#  2018-12-26                               36972.0
#  2018-12-27                               36972.0
#  2018-12-28                               36972.0
#  ...                                          ...
#  2020-08-02                               29523.0
#  2020-08-03                               29523.0
#  2020-08-04                               29523.0
#  2020-08-05                               29523.0
#  2020-08-06                               29523.0
#
#              Mithril%20trimmed%20set%20(sk) volume
#  date_obj
#  2018-12-24                                   17.0
#  2018-12-25                                   22.0
#  2018-12-26                                   37.0
#  2018-12-27                                   24.0
#  2018-12-28                                   57.0
#  ...                                           ...
#  2020-08-02                                   27.0
#  2020-08-03                                    9.0
#  2020-08-04                                   13.0
#  2020-08-05                                    9.0
#  2020-08-06                                    9.0
#
#  [589 rows x 2 columns],
#              Splitbark%20legs price  Splitbark%20legs volume
#  date_obj
#  2018-12-24                 24740.0                    448.0
#  2018-12-25                 25444.0                    484.0
#  2018-12-26                 25499.0                   1021.0
#  2018-12-27                 25554.0                    384.0
#  2018-12-28                 25778.0                   1038.0
#  ...                            ...                      ...
#  2020-08-02                 24862.0                    488.0
#  2020-08-03                 24223.0                    456.0
#  2020-08-04                 24005.0                    471.0
#  2020-08-05                 24479.0                    332.0
#  2020-08-06                 24479.0                    332.0
#
#  [589 rows x 2 columns],
#              Premade%20w'm%20crun' price  Premade%20w'm%20crun' volume
#  date_obj
#  2018-12-09                         40.0                           8.0
#  2018-12-10                         40.0                           0.0
#  2018-12-11                         40.0                          29.0
#  2018-12-12                         40.0                           6.0
#  2018-12-13                         40.0                           4.0
#  ...                                 ...                           ...
#  2020-08-02                         40.0                           1.0
#  2020-08-03                         40.0                           0.0
#  2020-08-04                         40.0                         536.0
#  2020-08-05                         40.0                           0.0
#  2020-08-06                         40.0                           0.0
#
#  [606 rows x 2 columns],
#              Willow%20shortbow price  Willow%20shortbow volume
#  date_obj
#  2018-09-24                     78.0                   10692.0
#  2018-09-25                     77.0                    3388.0
#  2018-09-26                     80.0                    7648.0
#  2018-09-27                     83.0                   16381.0
#  2018-09-28                     84.0                   13454.0
#  ...                             ...                       ...
#  2020-08-02                     95.0                   31860.0
#  2020-08-03                     96.0                   14612.0
#  2020-08-04                     96.0                   18907.0
#  2020-08-05                     96.0                   11232.0
#  2020-08-06                     97.0                   11232.0
#
#  [677 rows x 2 columns],
#              Turquoise%20robe%20bottoms price  \
#  date_obj
#  2018-12-09                             467.0
#  2018-12-10                             459.0
#  2018-12-11                             459.0
#  2018-12-12                             463.0
#  2018-12-13                             463.0
#  ...                                      ...
#  2020-08-02                             357.0
#  2020-08-03                             339.0
#  2020-08-04                             339.0
#  2020-08-05                             339.0
#  2020-08-06                             339.0
#
#              Turquoise%20robe%20bottoms volume
#  date_obj
#  2018-12-09                              669.0
#  2018-12-10                              120.0
#  2018-12-11                              189.0
#  2018-12-12                              225.0
#  2018-12-13                              176.0
#  ...                                       ...
#  2020-08-02                              183.0
#  2020-08-03                               54.0
#  2020-08-04                               58.0
#  2020-08-05                               38.0
#  2020-08-06                               38.0
#
#  [605 rows x 2 columns],
#              Elven%20skirt%20(white) price  Elven%20skirt%20(white) volume
#  date_obj
#  2019-07-25                         5000.0                           416.0
#  2019-07-25                         5087.0                           293.0
#  2019-07-26                         5156.0                           660.0
#  2019-07-27                         5375.0                           224.0
#  2019-07-28                         5375.0                           242.0
#  ...                                   ...                             ...
#  2020-08-02                         7448.0                            73.0
#  2020-08-03                         7448.0                            79.0
#  2020-08-04                         7249.0                            67.0
#  2020-08-05                         7249.0                            95.0
#  2020-08-06                         7249.0                            95.0
#
#  [381 rows x 2 columns],
#              Magic%20logs price  Magic%20logs volume
#  date_obj
#  2018-02-18              1064.0                 28.0
#  2018-02-19              1073.0                 29.0
#  2018-02-20              1077.0                 29.0
#  2018-02-21              1069.0                 30.0
#  2018-02-22              1076.0                 32.0
#  ...                        ...                  ...
#  2020-08-02               965.0            7233999.0
#  2020-08-03               960.0            5483318.0
#  2020-08-04               968.0            5689522.0
#  2020-08-05               970.0            4598217.0
#  2020-08-06               974.0            4598217.0
#
#  [887 rows x 2 columns],
#              Black%20desert%20robe price  Black%20desert%20robe volume
#  date_obj
#  2018-09-24                       1634.0                         156.0
#  2018-09-25                       1608.0                          49.0
#  2018-09-26                       1618.0                         126.0
#  2018-09-27                       1607.0                         336.0
#  2018-09-28                       1583.0                         211.0
#  ...                                 ...                           ...
#  2020-08-02                       1652.0                         387.0
#  2020-08-03                       1656.0                         289.0
#  2020-08-04                       1622.0                         292.0
#  2020-08-05                       1632.0                         215.0
#  2020-08-06                       1675.0                         215.0
#
#  [659 rows x 2 columns],
#              Air%20orb price  Air%20orb volume
#  date_obj
#  2018-09-24           1273.0         1722463.0
#  2018-09-25           1263.0          801350.0
#  2018-09-26           1260.0         1896451.0
#  2018-09-27           1300.0         3597995.0
#  2018-09-28           1345.0         2307360.0
#  ...                     ...               ...
#  2020-07-31           1114.0         7485423.0
#  2020-08-01           1115.0         2201518.0
#  2020-08-03           1147.0         4815696.0
#  2020-08-04           1145.0         5461791.0
#  2020-08-05           1137.0         5461791.0
#
#  [631 rows x 2 columns],
#              Leaf-bladed%20battleaxe price  Leaf-bladed%20battleaxe volume
#  date_obj
#  2018-12-07                       127204.0                          5540.0
#  2018-12-09                       131732.0                          3973.0
#  2018-12-10                       132086.0                          2326.0
#  2018-12-11                       131779.0                          3229.0
#  2018-12-12                       132272.0                          3867.0
#  ...                                   ...                             ...
#  2020-08-02                        79072.0                          2841.0
#  2020-08-03                        76995.0                          2362.0
#  2020-08-04                        75880.0                          3136.0
#  2020-08-05                        75262.0                          1926.0
#  2020-08-06                        71722.0                          1926.0
#
#  [605 rows x 2 columns],
#              Oak%20bookcase%20(flatpack) price  \
#  date_obj
#  2018-12-09                                2.0
#  2018-12-10                                2.0
#  2018-12-11                                2.0
#  2018-12-12                                2.0
#  2018-12-13                                2.0
#  ...                                       ...
#  2020-08-02                                1.0
#  2020-08-03                                1.0
#  2020-08-04                                1.0
#  2020-08-05                                1.0
#  2020-08-06                                1.0
#
#              Oak%20bookcase%20(flatpack) volume
#  date_obj
#  2018-12-09                                52.0
#  2018-12-10                               205.0
#  2018-12-11                               391.0
#  2018-12-12                               122.0
#  2018-12-13                               198.0
#  ...                                        ...
#  2020-08-02                                 1.0
#  2020-08-03                                 3.0
#  2020-08-04                               502.0
#  2020-08-05                                 0.0
#  2020-08-06                                 0.0
#
#  [605 rows x 2 columns],
#              Bagged%20flower price  Bagged%20flower volume
#  date_obj
#  2018-09-24                 5689.0                     1.0
#  2018-09-25                 5689.0                     1.0
#  2018-09-26                 5689.0                     2.0
#  2018-09-27                 5689.0                     3.0
#  2018-09-28                 5689.0                     4.0
#  ...                           ...                     ...
#  2020-08-02                 5757.0                    36.0
#  2020-08-03                 5757.0                    13.0
#  2020-08-04                 5757.0                    20.0
#  2020-08-05                 5757.0                    15.0
#  2020-08-06                 5757.0                    15.0
#
#  [661 rows x 2 columns],
#              Yew%20longbow price  Yew%20longbow volume
#  date_obj
#  2018-09-24                630.0             2150516.0
#  2018-09-25                632.0              864883.0
#  2018-09-26                653.0             2930076.0
#  2018-09-27                664.0             6014801.0
#  2018-09-28                652.0             4876030.0
#  ...                         ...                   ...
#  2020-08-02                512.0             9411296.0
#  2020-08-03                518.0             8303488.0
#  2020-08-04                524.0             8654444.0
#  2020-08-05                524.0             7079240.0
#  2020-08-06                520.0             7079240.0
#
#  [676 rows x 2 columns],
#              Premade%20ch'%20crunch price  Premade%20ch'%20crunch volume
#  date_obj
#  2018-12-09                          41.0                            2.0
#  2018-12-10                          41.0                            0.0
#  2018-12-11                          41.0                            0.0
#  2018-12-12                          41.0                            9.0
#  2018-12-13                          41.0                           17.0
#  ...                                  ...                            ...
#  2020-08-02                          42.0                            1.0
#  2020-08-03                          42.0                            1.0
#  2020-08-04                          42.0                          551.0
#  2020-08-05                          42.0                            0.0
#  2020-08-06                          42.0                            0.0
#
#  [605 rows x 2 columns],
#              Smouldering%20stone price  Smouldering%20stone volume
#  date_obj
#  2018-12-25                  1308712.0                       275.0
#  2018-12-26                  1335419.0                       590.0
#  2018-12-27                  1331031.0                       239.0
#  2018-12-28                  1355706.0                       681.0
#  2018-12-29                  1372257.0                       271.0
#  ...                               ...                         ...
#  2020-08-02                  1182856.0                       368.0
#  2020-08-03                  1223267.0                       300.0
#  2020-08-04                  1266939.0                       326.0
#  2020-08-05                  1290665.0                       257.0
#  2020-08-06                  1323745.0                       257.0
#
#  [589 rows x 2 columns],
#              Rune%20kiteshield price  Rune%20kiteshield volume
#  date_obj
#  2018-12-24                  32229.0                   34049.0
#  2018-12-25                  32134.0                   34837.0
#  2018-12-26                  32143.0                   76938.0
#  2018-12-27                  32181.0                   28537.0
#  2018-12-28                  32195.0                   79034.0
#  ...                             ...                       ...
#  2020-08-02                  32031.0                   76777.0
#  2020-08-03                  32047.0                   64196.0
#  2020-08-04                  32049.0                   72001.0
#  2020-08-05                  32047.0                   50295.0
#  2020-08-06                  32070.0                   50295.0
#
#  [590 rows x 2 columns],
#              Black%20cane price  Black%20cane volume
#  date_obj
#  2018-09-24             15994.0                 26.0
#  2018-09-25             15994.0                  5.0
#  2018-09-26             16199.0                 18.0
#  2018-09-27             16199.0                 81.0
#  2018-09-28             16199.0                 42.0
#  ...                        ...                  ...
#  2020-08-02             17997.0                 37.0
#  2020-08-03             17997.0                 43.0
#  2020-08-04             17997.0                 44.0
#  2020-08-05             18897.0                 26.0
#  2020-08-06             18897.0                 26.0
#
#  [657 rows x 2 columns],
#              Mithril%20med%20helm price  Mithril%20med%20helm volume
#  date_obj
#  2018-12-09                       297.0                       6479.0
#  2018-12-10                       304.0                       4496.0
#  2018-12-11                       304.0                       7098.0
#  2018-12-12                       302.0                       6897.0
#  2018-12-13                       306.0                       5974.0
#  ...                                ...                          ...
#  2020-08-02                       285.0                       4907.0
#  2020-08-03                       288.0                       4888.0
#  2020-08-04                       289.0                       4606.0
#  2020-08-05                       292.0                       3695.0
#  2020-08-06                       292.0                       3695.0
#
#  [606 rows x 2 columns],
#              Pirate%20bandana%20(brown) price  \
#  date_obj
#  2018-12-24                             246.0
#  2018-12-25                             246.0
#  2018-12-26                             257.0
#  2018-12-27                             257.0
#  2018-12-28                             268.0
#  ...                                      ...
#  2020-08-02                             533.0
#  2020-08-03                             533.0
#  2020-08-04                             506.0
#  2020-08-05                             506.0
#  2020-08-06                             506.0
#
#              Pirate%20bandana%20(brown) volume
#  date_obj
#  2018-12-24                               44.0
#  2018-12-25                               69.0
#  2018-12-26                              131.0
#  2018-12-27                               73.0
#  2018-12-28                              206.0
#  ...                                       ...
#  2020-08-02                               64.0
#  2020-08-03                              152.0
#  2020-08-04                               40.0
#  2020-08-05                               57.0
#  2020-08-06                               57.0
#
#  [589 rows x 2 columns],
#              Shoe%20box%20(flatpack) price  Shoe%20box%20(flatpack) volume
#  date_obj
#  2018-12-07                            1.0                            49.0
#  2018-12-09                            1.0                             6.0
#  2018-12-10                            1.0                             0.0
#  2018-12-11                            1.0                             0.0
#  2018-12-12                            1.0                             0.0
#  ...                                   ...                             ...
#  2020-08-02                            2.0                             0.0
#  2020-08-03                            2.0                             0.0
#  2020-08-04                            2.0                             1.0
#  2020-08-05                            2.0                             0.0
#  2020-08-06                            2.0                             0.0
#
#  [607 rows x 2 columns],
#              Armadyl%20stole price  Armadyl%20stole volume
#  date_obj
#  2018-09-24                 7866.0                    89.0
#  2018-09-25                 7866.0                    31.0
#  2018-09-26                 7826.0                    75.0
#  2018-09-27                 7758.0                   168.0
#  2018-09-28                 7618.0                   158.0
#  ...                           ...                     ...
#  2020-08-02                 7133.0                   260.0
#  2020-08-03                 7348.0                   216.0
#  2020-08-04                 7551.0                   208.0
#  2020-08-05                 7568.0                   185.0
#  2020-08-06                 7396.0                   185.0
#
#  [656 rows x 2 columns],
#              Wooden%20bench%20(flatpack) price  \
#  date_obj
#  2018-09-24                               29.0
#  2018-09-25                               29.0
#  2018-09-26                               29.0
#  2018-09-27                               29.0
#  2018-09-28                               29.0
#  ...                                       ...
#  2020-08-02                               19.0
#  2020-08-03                               19.0
#  2020-08-04                               19.0
#  2020-08-05                               19.0
#  2020-08-06                               19.0
#
#              Wooden%20bench%20(flatpack) volume
#  date_obj
#  2018-09-24                                 0.0
#  2018-09-25                                 1.0
#  2018-09-26                                 0.0
#  2018-09-27                                 1.0
#  2018-09-28                                 0.0
#  ...                                        ...
#  2020-08-02                                 0.0
#  2020-08-03                                 0.0
#  2020-08-04                                 0.0
#  2020-08-05                                 0.0
#  2020-08-06                                 0.0
#
#  [675 rows x 2 columns],
#              Onyx%20dragon%20bolts price  Onyx%20dragon%20bolts volume
#  date_obj
#  2018-12-07                       9669.0                        3118.0
#  2018-12-09                       9746.0                         987.0
#  2018-12-10                       9746.0                        5215.0
#  2018-12-11                       9746.0                        6855.0
#  2018-12-12                       9746.0                        3672.0
#  ...                                 ...                           ...
#  2020-08-02                       9015.0                      158736.0
# ...
#  2020-08-06              177.0               507.0
#
#  [602 rows x 2 columns],
#              Splitbark%20body price  Splitbark%20body volume
#  date_obj
#  2018-12-24                 28617.0                    506.0
#  2018-12-25                 28024.0                    524.0
#  2018-12-26                 27949.0                   1181.0
#  2018-12-27                 28301.0                    528.0
#  2018-12-28                 29033.0                   1275.0
#  ...                            ...                      ...
#  2020-08-02                 28331.0                    698.0
#  2020-08-03                 27631.0                    589.0
#  2020-08-04                 27925.0                    688.0
#  2020-08-05                 29013.0                    454.0
#  2020-08-06                 29546.0                    454.0
#
#  [590 rows x 2 columns],
#              Iron%20set%20(sk) price  Iron%20set%20(sk) volume
#  date_obj
#  2018-12-09                    276.0                    1592.0
#  2018-12-10                    276.0                    1098.0
#  2018-12-11                    278.0                     482.0
#  2018-12-13                    301.0                     406.0
#  2018-12-14                    312.0                     365.0
#  ...                             ...                       ...
#  2020-08-02                    524.0                     214.0
#  2020-08-03                    536.0                      78.0
#  2020-08-04                    536.0                     157.0
#  2020-08-05                    549.0                     108.0
#  2020-08-06                    549.0                     108.0
#
#  [603 rows x 2 columns],
#              Guthix%20crozier price  Guthix%20crozier volume
#  date_obj
#  2018-12-24                  5615.0                     93.0
#  2018-12-25                  5634.0                    133.0
#  2018-12-26                  5626.0                    227.0
#  2018-12-27                  5591.0                     94.0
#  2018-12-28                  5569.0                    269.0
#  ...                            ...                      ...
#  2020-08-02                  3298.0                     83.0
#  2020-08-03                  3445.0                     63.0
#  2020-08-04                  3575.0                     73.0
#  2020-08-05                  3618.0                     54.0
#  2020-08-06                  3735.0                     54.0
#
#  [587 rows x 2 columns],
#              Law%20rune price  Law%20rune volume
#  date_obj
#  2018-02-18             155.0              116.0
#  2018-02-19             161.0              119.0
#  2018-02-20             166.0              119.0
#  2018-02-21             174.0              120.0
#  2018-02-22             179.0              129.0
#  ...                      ...                ...
#  2020-08-02             150.0         28376859.0
#  2020-08-03             147.0         21874775.0
#  2020-08-04             147.0         25021081.0
#  2020-08-05             145.0         18152493.0
#  2020-08-06             144.0         18152493.0
#
#  [887 rows x 2 columns],
#              Wrath%20tiara price  Wrath%20tiara volume
#  date_obj
#  2018-09-24               3808.0                1626.0
#  2018-09-25               3808.0                 337.0
#  2018-09-26               3808.0                 667.0
#  2018-09-27               3808.0                1912.0
#  2018-09-28               3808.0                1059.0
#  ...                         ...                   ...
#  2020-08-02                106.0                 667.0
#  2020-08-03                106.0                2546.0
#  2020-08-04                106.0                 637.0
#  2020-08-05                106.0                 383.0
#  2020-08-06                106.0                 383.0
#
#  [677 rows x 2 columns],
#              Kebbit%20bolts price  Kebbit%20bolts volume
#  date_obj
#  2018-12-09                  88.0               484792.0
#  2018-12-10                  89.0               181980.0
#  2018-12-11                  91.0               316610.0
#  2018-12-12                  92.0               404508.0
#  2018-12-13                  92.0               317470.0
#  ...                          ...                    ...
#  2020-08-02                 284.0               142972.0
#  2020-08-03                 284.0               127530.0
#  2020-08-04                 288.0                79170.0
#  2020-08-05                 303.0                82830.0
#  2020-08-06                 315.0                82830.0
#
#  [600 rows x 2 columns],
#              Karil's%20leathertop price  Karil's%20leathertop volume
#  date_obj
#  2018-12-25                   2153080.0                       2165.0
#  2018-12-26                   2210672.0                       4793.0
#  2018-12-27                   2307242.0                       2038.0
#  2018-12-28                   2319959.0                       5175.0
#  2018-12-29                   2386976.0                       2708.0
#  ...                                ...                          ...
#  2020-08-02                   1895586.0                       4159.0
#  2020-08-03                   1910242.0                       3305.0
#  2020-08-04                   1899910.0                       3647.0
#  2020-08-05                   1884797.0                       2754.0
#  2020-08-06                   1884716.0                       2754.0
#
#  [587 rows x 2 columns],
#              Riyl%20remains price  Riyl%20remains volume
#  date_obj
#  2018-12-09                 646.0                 1425.0
#  2018-12-10                 646.0                   78.0
#  2018-12-11                 646.0                 4485.0
#  2018-12-12                 646.0                 4178.0
#  2018-12-13                 646.0                 3343.0
#  ...                          ...                    ...
#  2020-08-02                 271.0                  414.0
#  2020-08-03                 271.0                   42.0
#  2020-08-04                 271.0                  223.0
#  2020-08-05                 271.0                  347.0
#  2020-08-06                 271.0                  347.0
#
#  [605 rows x 2 columns],
#              Holy%20sandals price  Holy%20sandals volume
#  date_obj
#  2018-12-25             1373735.0                  585.0
#  2018-12-26             1442422.0                 1395.0
#  2018-12-27             1514544.0                  604.0
#  2018-12-28             1590272.0                 1602.0
#  2018-12-29             1669786.0                  841.0
#  ...                          ...                    ...
#  2020-08-02             1156259.0                  553.0
#  2020-08-03             1148001.0                  414.0
#  2020-08-04             1146081.0                  502.0
#  2020-08-05             1150036.0                  343.0
#  2020-08-06             1141291.0                  343.0
#
#  [584 rows x 2 columns],
#              Uncooked%20meat%20pie price  Uncooked%20meat%20pie volume
#  date_obj
#  2018-12-09                        578.0                        2545.0
#  2018-12-10                        578.0                       16257.0
#  2018-12-11                        578.0                       12285.0
#  2018-12-12                        578.0                       22897.0
#  2018-12-13                        578.0                        5652.0
#  ...                                 ...                           ...
#  2020-08-02                        594.0                         186.0
#  2020-08-03                        594.0                        1271.0
#  2020-08-04                        594.0                         742.0
#  2020-08-05                        594.0                         459.0
#  2020-08-06                        594.0                         459.0
#
#  [606 rows x 2 columns],
#              Toktz-xil-ak price  Toktz-xil-ak volume
#  date_obj
#  2018-09-24            276037.0                233.0
#  2018-09-25            276037.0                100.0
#  2018-09-26            274292.0                244.0
#  2018-09-27            274292.0                418.0
#  2018-09-28            276588.0                354.0
#  ...                        ...                  ...
#  2020-08-02            436915.0               1180.0
#  2020-08-03            445432.0                930.0
#  2020-08-04            467519.0               1168.0
#  2020-08-05            486663.0                755.0
#  2020-08-06            505248.0                755.0
#
#  [675 rows x 2 columns],
#              Leather%20chaps price  Leather%20chaps volume
#  date_obj
#  2018-12-07                    1.0                343208.0
#  2018-12-09                    1.0                297662.0
#  2018-12-10                    1.0                164432.0
#  2018-12-11                    1.0                238935.0
#  2018-12-12                    1.0                270403.0
#  ...                           ...                     ...
#  2020-08-02                    1.0                130079.0
#  2020-08-03                    1.0                 97566.0
#  2020-08-04                    1.0                 98002.0
#  2020-08-05                    2.0                 71874.0
#  2020-08-06                    2.0                 71874.0
#
#  [604 rows x 2 columns],
#              Water%20talisman price  Water%20talisman volume
#  date_obj
#  2018-09-24                   184.0                  22347.0
#  2018-09-25                   194.0                   8445.0
#  2018-09-26                   196.0                  44531.0
#  2018-09-27                   188.0                  35560.0
#  2018-09-28                   179.0                  27130.0
#  ...                            ...                      ...
#  2020-08-02                   194.0                 162141.0
#  2020-08-03                   196.0                  93604.0
#  2020-08-04                   204.0                 107189.0
#  2020-08-05                   205.0                  54068.0
#  2020-08-06                   209.0                  54068.0
#
#  [676 rows x 2 columns],
#              Willow%20comp%20bow price  Willow%20comp%20bow volume
#  date_obj
#  2018-09-24                     4508.0                        82.0
#  2018-09-25                     4373.0                        36.0
#  2018-09-26                     4281.0                       131.0
#  2018-09-27                     4255.0                       130.0
#  2018-09-28                     4153.0                       123.0
#  ...                               ...                         ...
#  2020-08-02                     3482.0                       135.0
#  2020-08-03                     3500.0                        80.0
#  2020-08-04                     3573.0                       102.0
#  2020-08-05                     3556.0                        93.0
#  2020-08-06                     3522.0                        93.0
#
#  [676 rows x 2 columns],
#              Mind%20helmet price  Mind%20helmet volume
#  date_obj
#  2018-12-24               1546.0                 295.0
#  2018-12-25               1552.0                 152.0
#  2018-12-26               1552.0                 342.0
#  2018-12-27               1571.0                 129.0
#  2018-12-28               1571.0                 351.0
#  ...                         ...                   ...
#  2020-08-02               1506.0                 177.0
#  2020-08-03               1506.0                 194.0
#  2020-08-04               1495.0                 124.0
#  2020-08-05               1495.0                 200.0
#  2020-08-06               1498.0                 200.0
#
#  [589 rows x 2 columns],
#              Bronze%20full%20helm%20(t) price  \
#  date_obj
#  2018-09-24                           13919.0
#  2018-09-25                           13919.0
#  2018-09-26                           14033.0
#  2018-09-27                           14033.0
#  2018-09-28                           14033.0
#  ...                                      ...
#  2020-08-02                           11465.0
#  2020-08-03                           10965.0
#  2020-08-04                           10965.0
#  2020-08-05                           10476.0
#  2020-08-06                           10476.0
#
#              Bronze%20full%20helm%20(t) volume
#  date_obj
#  2018-09-24                               15.0
#  2018-09-25                               10.0
#  2018-09-26                               22.0
#  2018-09-27                               30.0
#  2018-09-28                               24.0
#  ...                                       ...
#  2020-08-02                               32.0
#  2020-08-03                               29.0
#  2020-08-04                               29.0
#  2020-08-05                               16.0
#  2020-08-06                               16.0
#
#  [663 rows x 2 columns],
#              Lime%20slices price  Lime%20slices volume
#  date_obj
#  2018-12-09                174.0                  20.0
#  2018-12-10                174.0                   2.0
#  2018-12-11                174.0                  63.0
#  2018-12-12                174.0                  60.0
#  2018-12-13                174.0                  58.0
#  ...                         ...                   ...
#  2020-08-02                152.0                   9.0
#  2020-08-03                152.0                  46.0
#  2020-08-04                152.0                  17.0
#  2020-08-05                152.0                  45.0
#  2020-08-06                152.0                  45.0
#
#  [602 rows x 2 columns],
#              Emerald%20ring price  Emerald%20ring volume
#  date_obj
#  2018-12-24                 716.0               180025.0
#  2018-12-25                 718.0               199801.0
#  2018-12-26                 710.0               447338.0
#  2018-12-27                 704.0               179474.0
#  2018-12-28                 697.0               440358.0
#  ...                          ...                    ...
#  2020-08-02                 653.0               322177.0
#  2020-08-03                 650.0               280140.0
#  2020-08-04                 653.0               297664.0
#  2020-08-05                 660.0               217013.0
#  2020-08-06                 658.0               217013.0
#
#  [580 rows x 2 columns],
#              Anguish%20ornament%20kit price  Anguish%20ornament%20kit volume
#  date_obj
#  2018-09-24                      16418353.0                             81.0
#  2018-09-25                      16677705.0                             41.0
#  2018-09-26                      16785409.0                            103.0
#  2018-09-27                      16696024.0                            187.0
#  2018-09-28                      16838210.0                            117.0
#  ...                                    ...                              ...
#  2020-08-02                       9806807.0                            625.0
#  2020-08-03                       9691100.0                            543.0
#  2020-08-04                       9679368.0                            527.0
#  2020-08-05                       9572471.0                            390.0
#  2020-08-06                       9467059.0                            390.0
#
#  [659 rows x 2 columns],
#  ...]

# %%
def save_dfs(item_dfs):
    for df in item_dfs:
        try:
            df.to_csv(f'./data/wiki_prices/{df.columns[0]}.csv')
        except:
            pass

# %%
save_dfs(item_dfs)

# %%
def load_dfs(drop_blank=True):
    item_dfs = []
    for name in list(os.walk('./data/wiki_prices'))[0][2]:
        df = pd.read_csv(f'./data/wiki_prices/{name}')
        df = df.set_index(df.columns[0])
#         if drop_blank:
#             if df.empty:
#                 item_dfs.append(df)
#         else:
#             item_dfs.append(df)
        item_dfs.append(df)
    return item_dfs

# %%
item_dfs = load_dfs()

# %%
len(item_dfs)
# Out:
# 3147

# %%
type(item_dfs)
# Out:
# list

# %%
cleaned_item_names[0]
# Out:
# 'Potato%20seed'

# %%
for item_df in item_dfs:
    try:
        col = item_df.columns[0]
    except:
        invalid_dfs += 1 
        print(item_df)

# %%
retrieved_names = [item_df.columns[0][:-6] for item_df in item_dfs]

# %%
len(retrieved_names)
# Out:
# 3147

# %%
len(item_dfs)
# Out:
# 3147

# %%
df = pd.DataFrame({'name': retrieved_names, 'price_df': item_dfs})

# %% [markdown]
# # Feature creation

# %%
#item_df_training = tl_df['price_df'][300]

# %%
days_back = 90

rolling_averages = [3,7,14,21,30,60,90]

days_ahead_to_predict = 4

# %%
def create_predictive_features(price_df):
    item_df_training = price_df
    item_name = item_df_training.columns[0]
    for i in range(days_back):
        item_df_training[f'{item_name} {i} days ago'] = item_df_training[item_name].shift(i)
    for i in range(days_back):
        item_df_training[f'{item_name} {i} delta days ago'] = item_df_training[item_name].shift(i) - item_df_training[item_name]
    for rolling_average in rolling_averages:
        item_df_training[f'{item_name} {rolling_average} day rolling average'] = item_df_training[item_name].rolling(rolling_average).mean()
    for rolling_average in rolling_averages:
        item_df_training[f'{item_name} delta {rolling_average} day rolling average'] = item_df_training[item_name] - item_df_training[f'{item_name} {rolling_average} day rolling average']
    item_df_training['Y'] = item_df_training[item_name].shift(-1*days_ahead_to_predict)
    return item_df_training

# %%
#price_df = tl_df['price_df'][300]

# %%
def trim_df(item_df_training):
    trimmed_df = item_df_training.dropna(how='any')
    return trimmed_df

# %% [markdown]
# # SGD LR

# %%
def create_model(tl_df_row):
    trimmed_df = tl_df_row['trimmed_df']
    try:
        X = trimmed_df.drop(['Y'], axis=1)
        y = trimmed_df['Y']
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, shuffle=False)
        regr = linear_model.LinearRegression()
        regr.fit(X_train, y_train)
        y_pred = regr.predict(X_test)
        mean_squared_error = sklearn.metrics.mean_squared_error(y_test, y_pred)
        r2_score = sklearn.metrics.r2_score(y_test, y_pred)
        return (regr, y_pred, y_test, mean_squared_error, r2_score)
    except:
        return (0, 0, 0, 0, 0)

# %%
#plt.scatter(y_test, y_pred)

# %% [markdown]
# # "Backtest"

# %%
starting_cash = 10**7

# %%
slippage = 0
thresh_buy = 0.00
thresh_sell = 0
max_volume_buy = 0.01

# %%
def should_buy(row):
    if row['perc predicted increase'] > thresh_buy:
        return True

def should_sell(row):
    if row['perc predicted increase'] < thresh_sell:
        return True
    
def buy_price(row):
    return row['current_price']

def sell_price(row):
    return row['current_price']

def max_buy(row):
    d_stock = max(
        min(
        (row['starting_cash']//buy_price(row)),
        math.floor(row['volume']*max_volume_buy)
        ),
        0
    )
    d_cash = -1 * d_stock * buy_price(row)
    return (d_stock, d_cash)

def max_sell(row):
    d_stock = -1 * max(
        0,
        min(row['starting_stock'],
        math.floor(row['volume'] * max_volume_buy)
        )
    )
    d_cash = d_stock *-1 * sell_price(row)
    return (d_stock, d_cash)

# %%
def get_ending_cash(record_df):
    last_row = record_df.iloc[-1,:]
    cash = last_row['ending_cash']
    cash += sell_price(last_row) * last_row['ending_stock']
    return cash

# %%
def create_backtest_df(tl_df_row):
    try:
        y_pred = tl_df_row['y_pred']
        y_test = tl_df_row['y_test']
        item_df_training = tl_df_row['item_df_training']
        item_name = tl_df_row['name']

        bt_df = pd.concat([pd.Series(y_pred, index= y_test.index, name='Prediction'), y_test.rename(index='Y')], axis=1)
        bt_df['Y + 1'] = bt_df['Y'].shift(-1)
        bt_df['Y - 1'] = bt_df['Y'].shift(1)


        bt_df = bt_df.fillna(method='ffill').fillna(method='bfill')

        volume_column = f'{item_name} volume'
        volume = item_df_training[volume_column]

        bt_df = bt_df.join(item_df_training[volume_column].rename(index='volume'))
        bt_df = bt_df.join(item_df_training[f'{item_name} price'].rename(index='current_price'))
        bt_df['perc predicted increase'] = (bt_df['Prediction'] - bt_df['current_price'])/bt_df['current_price']

        bt_df['starting_stock'] = 0
        bt_df['starting_cash'] = 0
        bt_df['ending_stock'] = 0
        bt_df['ending_cash'] = 0

        bt_df.loc[bt_df.index[0], 'starting_cash'] = starting_cash
        bt_df.loc[bt_df.index[0], 'ending_cash'] = starting_cash

        bt_df['action'] = ''

        copy_df = bt_df.copy()
        record_df = bt_df.copy()

        first_row = True
        for i, row in copy_df.iterrows():
            current_row = row
            if first_row:
                prev_row = current_row
                first_row = False
                continue
            current_row['starting_cash'] = prev_row['ending_cash']
            current_row['starting_stock'] = prev_row['ending_stock']
            cash = current_row['starting_cash']
            stock = current_row['starting_stock']
            if should_buy(current_row):
                d_stock, d_cash = max_buy(current_row)
                cash += d_cash
                stock += d_stock
                current_row['action'] = f'Buying + {d_stock} stock, - {d_cash} cash'
            elif should_sell(row):
                d_stock, d_cash = max_sell(current_row)
                cash += d_cash
                stock += d_stock
                current_row['action'] = f'Selling + {d_stock} stock, + {d_cash} cash'
            else:
                current_row['action'] = 'hold'
            current_row['ending_cash'] = cash
            current_row['ending_stock'] = stock
            record_df.loc[i, :] = current_row
            prev_row = current_row
        roi = get_ending_cash(record_df)/starting_cash
        last_perc_prediction = bt_df
        return (roi, record_df)
    except:
        return (0, 0)

# %% [markdown]
# # Predict for right now

# %%
def make_predictions(tl_df_row):
    try:
        item_name = tl_df_row['name']
        regr = tl_df_row['regr']
        item_df_training = tl_df_row['item_df_training']
        current_price = item_df_training.loc[item_df_training.index[-1], f'{item_name} price']
        pred_price = regr.predict(np.array(item_df_training.drop('Y', axis=1).loc[item_df_training.index[-1],:]).reshape(1, -1))[0]
        perc_pred_increase = (pred_price - current_price)/(current_price)
        last_day = item_df_training.index[-1]
        return (perc_pred_increase, last_day, current_price)
    except:
        return(0, 0, 0)

# %% [markdown]
# # Filter and find trades

# %%
r2_score_thresh = .85
roi_thresh = 1.05
perc_pred_increase_thresh = 0.03

# %%
batch_size = 100

# %%
df_list = []

# %%
bought = pd.read_csv('data/bought')

# %%
bought['name'].values
# Out:
# array(['Black%20shield%20(h1)', 'Avantoe%20seed', 'Iron%20ore', 'Black%20wizard%20hat%20(g)',
#        'Bottomless%20compost%20bucket', 'Mole%20slippers', 'Wooden%20shield%20(g)', "Ahrim's%20robeskirt"],
#       dtype=object)

# %%
tl_df['item_df_training']

# %%
for i in range(0,df.shape[0],batch_size):
    tl_df = df.iloc[i:i+100,:]
    
    tl_df['item_df_training'] = tl_df['price_df'].apply(create_predictive_features)

    tl_df['trimmed_df'] = tl_core'] = zip(*tl_df.apply(create_model, axis=1))
df['item_df_training'].apply(trim_df)

    tl_df['regr'], tl_df['y_pred'], tl_df['y_test'], tl_df['mean_squared_error'], tl_df['r2_score'] = zip(*tl_df.apply(create_model, axis=1))


    tl_df['roi'], tl_df['record_df'] = zip(*tl_df.apply(create_backtest_df, axis=1))


    tl_df.sort_values(by='roi', ascending = False)

    tl_df['perc_pred_increase'], tl_df['last_day'], tl_df['current_price'] = zip(*tl_df.apply(make_predictions, axis=1))


    filter_tl_df = tl_df.copy()

    filter_tl_df = filter_tl_df.dropna(how='any')

    filter_tl_df =filter_tl_df.loc[filter_tl_df['r2_score'].apply(lambda x: type(x)) != list]

    filter_tl_df = filter_tl_df.loc[filter_tl_df['r2_score'] > r2_score_thresh]

    print(filter_tl_df.shape)

    filter_tl_df = filter_tl_df.loc[filter_tl_df['roi'] > roi_thresh]

    print(filter_tl_df.shape)

    filter_tl_df = filter_tl_df.loc[
            (filter_tl_df['perc_pred_increase'] > perc_pred_increase_thresh) \
        | (filter_tl_df['name'].isin(bought['name']))
                                   ]

    print(filter_tl_df.shape)

    print(filter_tl_df)
    df_list.append(filter_tl_df)
# Out:
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (24, 14)
# (3, 14)
# (0, 14)
# Empty DataFrame
# Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day, current_price]
# Index: []
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (26, 14)
# (2, 14)
# (1, 14)
#                            name  \
# 162  Black%20wizard%20hat%20(g)
#
#                                               price_df  \
# 162              Black%20wizard%20hat%20(g) price  ...
#
#                                       item_df_training  \
# 162              Black%20wizard%20hat%20(g) price  ...
#
#                                             trimmed_df                regr  \
# 162              Black%20wizard%20hat%20(g) price  ...  LinearRegression()
#
#                                                 y_pred  \
# 162  [379372.0437362031, 374438.4890487031, 355055....
#
#                                                 y_test  mean_squared_error  \
# 162  date_obj
# 2020-04-10    364179.0
# 2020-04-11    ...        1.045895e+08
#
#      r2_score      roi                                          record_df  \
# 162  0.956981  1.22286                 Prediction         Y     Y + 1 ...
#
#      perc_pred_increase    last_day  current_price
# 162            0.045882  2020-08-06       278412.0
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (27, 14)
# (1, 14)
# (0, 14)
# Empty DataFrame
# Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day, current_price]
# Index: []
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (25, 14)
# (0, 14)
# (0, 14)
# Empty DataFrame
# Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day, current_price]
# Index: []
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (16, 14)
# (1, 14)
# (1, 14)
#                       name                                           price_df  \
# 403  Black%20shield%20(h1)              Black%20shield%20(h1) price  Black...
#
#                                       item_df_training  \
# 403              Black%20shield%20(h1) price  Black...
#
#                                             trimmed_df                regr  \
# 403              Black%20shield%20(h1) price  Black...  LinearRegression()
#
#                                                 y_pred  \
# 403  [2406.5847933266073, 2445.6079866859823, 2518....
#
#                                                 y_test  mean_squared_error  \
# 403  date_obj
# 2020-04-10    2522.0
# 2020-04-11    25...       193299.285328
#
#      r2_score       roi                                          record_df  \
# 403  0.934113  1.086539               Prediction       Y   Y + 1   Y - ...
#
#      perc_pred_increase    last_day  current_price
# 403            0.018047  2020-08-06         9198.0
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (25, 14)
# (5, 14)
# (2, 14)
#                name                                           price_df  \
# 537  Avantoe%20seed              Avantoe%20seed price  Avantoe%20se...
# 566  Molten%20glass              Molten%20glass price  Molten%20gla...
#
#                                       item_df_training  \
# 537              Avantoe%20seed price  Avantoe%20se...
# 566              Molten%20glass price  Molten%20gla...
#
#                                             trimmed_df                regr  \
# 537              Avantoe%20seed price  Avantoe%20se...  LinearRegression()
# 566              Molten%20glass price  Molten%20gla...  LinearRegression()
#
#                                                 y_pred  \
# 537  [903.9546602037217, 995.6339051988389, 1060.42...
# 566  [151.23334600354846, 151.58675614458878, 149.2...
#
#                                                 y_test  mean_squared_error  \
# 537  date_obj
# 2020-04-10    1017.0
# 2020-04-11    10...        17219.925381
# 566  date_obj
# 2020-02-25    150.0
# 2020-02-26    151...           39.314591
#
#      r2_score       roi                                          record_df  \
# 537  0.888172  1.077821               Prediction       Y   Y + 1   Y - ...
# 566  0.875348  1.072711              Prediction      Y  Y + 1  Y - 1   ...
#
#      perc_pred_increase    last_day  current_price
# 537            0.089764  2020-08-05          482.0
# 566            0.043016  2020-08-06          116.0
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (27, 14)
# (1, 14)
# (0, 14)
# Empty DataFrame
# Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day, current_price]
# Index: []
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (27, 14)
# (3, 14)
# (0, 14)
# Empty DataFrame
# Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day, current_price]
# Index: []
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (27, 14)
# (4, 14)
# (1, 14)
#                       name                                           price_df  \
# 813  Black%20dragon%20mask              Black%20dragon%20mask price  Black...
#
#                                       item_df_training  \
# 813              Black%20dragon%20mask price  Black...
#
#                                             trimmed_df                regr  \
# 813              Black%20dragon%20mask price  Black...  LinearRegression()
#
#                                                 y_pred  \
# 813  [14779.960978550194, 14565.765177768944, 14224...
#
#                                                 y_test  mean_squared_error  \
# 813  date_obj
# 2020-04-10    13752.0
# 2020-04-11    1...       835969.557629
#
#      r2_score       roi                                          record_df  \
# 813  0.931644  1.079196                Prediction        Y    Y + 1    ...
#
#      perc_pred_increase    last_day  current_price
# 813            0.050376  2020-08-06        28100.0
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (28, 14)
# (3, 14)
# (1, 14)
#                     name                                           price_df  \
# 916  Ahrim's%20robeskirt              Ahrim's%20robeskirt price  Ahrim's...
#
#                                       item_df_training  \
# 916              Ahrim's%20robeskirt price  Ahrim's...
#
#                                             trimmed_df                regr  \
# 916              Ahrim's%20robeskirt price  Ahrim's...  LinearRegression()
#
#                                                 y_pred  \
# 916  [2209740.230924187, 2214525.230924187, 2302695...
#
#                                                 y_test  mean_squared_error  \
# 916  date_obj
# 2020-04-10    2296793.0
# 2020-04-11   ...        1.280292e+10
#
#      r2_score       roi                                          record_df  \
# 916   0.85545  1.213372                Prediction          Y      Y + 1...
#
#      perc_pred_increase    last_day  current_price
# 916            0.013726  2020-08-06      1707268.0
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (25, 14)
# (2, 14)
# (0, 14)
# Empty DataFrame
# Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day, current_price]
# Index: []
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (21, 14)
# (1, 14)
# (0, 14)
# Empty DataFrame
# Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day, current_price]
# Index: []
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (25, 14)
# (0, 14)
# (0, 14)
# Empty DataFrame
# Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day, current_price]
# Index: []
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (34, 14)
# (2, 14)
# (0, 14)
# Empty DataFrame
# Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day, current_price]
# Index: []
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (28, 14)
# (0, 14)
# (0, 14)
# Empty DataFrame
# Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day, current_price]
# Index: []
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (34, 14)
# (4, 14)
# (0, 14)
# Empty DataFrame
# Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day, current_price]
# Index: []
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (27, 14)
# (1, 14)
# (0, 14)
# Empty DataFrame
# Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day, current_price]
# Index: []
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (25, 14)
# (4, 14)
# (1, 14)
#             name                                           price_df  \
# 1868  Iron%20ore              Iron%20ore price  Iron%20ore volum...
#
#                                        item_df_training  \
# 1868              Iron%20ore price  Iron%20ore volum...
#
#                                              trimmed_df                regr  \
# 1868              Iron%20ore price  Iron%20ore volum...  LinearRegression()
#
#                                                  y_pred  \
# 1868  [43.61558479355354, 45.38732281106253, 41.8277...
#
#                                                  y_test  mean_squared_error  \
# 1868  date_obj
# 2020-02-25    43.0
# 2020-02-26    43.0...           119.40746
#
#       r2_score       roi                                          record_df  \
# 1868  0.930788  3.374128              Prediction     Y  Y + 1  Y - 1    ...
#
#       perc_pred_increase    last_day  current_price
# 1868            0.026681  2020-08-06           78.0
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (31, 14)
# (8, 14)
# (2, 14)
#                  name                                           price_df  \
# 1903  Team%20cape%20x              Team%20cape%20x price  Team%20cape...
# 1974    Raw%20lobster              Raw%20lobster price  Raw%20lobster...
#
#                                        item_df_training  \
# 1903              Team%20cape%20x price  Team%20cape...
# 1974              Raw%20lobster price  Raw%20lobster...
#
#                                              trimmed_df                regr  \
# 1903              Team%20cape%20x price  Team%20cape...  LinearRegression()
# 1974              Raw%20lobster price  Raw%20lobster...  LinearRegression()
#
#                                                  y_pred  \
# 1903  [1709621.8247604927, 1659467.3247604927, 16482...
# 1974  [116.07391029436896, 113.52144485828204, 109.3...
#
#                                                  y_test  mean_squared_error  \
# 1903  date_obj
# 2020-04-21    1641159.0
# 2020-04-22   ...        3.910958e+09
# 1974  date_obj
# 2020-02-29    122.0
# 2020-03-01    119...        1.869886e+02
#
#       r2_score       roi                                          record_df  \
# 1903  0.910630  1.364283                Prediction          Y      Y + 1...
# 1974  0.870432  1.666840              Prediction      Y  Y + 1  Y - 1   ...
#
#       perc_pred_increase    last_day  current_price
# 1903            0.031985  2020-08-06      2070510.0
# 1974            0.037130  2020-08-06          215.0
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (27, 14)
# (2, 14)
# (0, 14)
# Empty DataFrame
# Columns: [name, price_df, item_df_training, trimmed_df, regr, y_pred, y_test, mean_squared_error, r2_score, roi, record_df, perc_pred_increase, last_day, current_price]
# Index: []
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# (27, 14)
# (4, 14)
# (1, 14)
#             name                                           price_df  \
# 2158  Red%20bead              Red%20bead price  Red%20bead volum...
#
#                                        item_df_training  \
# 2158              Red%20bead price  Red%20bead volum...
#
#                                              trimmed_df                regr  \
# 2158              Red%20bead price  Red%20bead volum...  LinearRegression()
#
#                                                  y_pred  \
# 2158  [782.3452955083033, 777.6791578129908, 804.422...
#
#                                                  y_test  mean_squared_error  \
# 2158  date_obj
# 2020-04-24     810.0
# 2020-04-25     8...         19451.37449
#
#       r2_score       roi                                          record_df  \
# 2158  0.856609  1.346445               Prediction       Y   Y + 1   Y - ...
#
#       perc_pred_increase    last_day  current_price
# 2158            0.040103  2020-08-06         2567.0
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adamh/PycharmProjects/stonks/model/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
filter_tl_df

# %%
df_list

# %%
trading_df = pd.concat(df_list, axis=0).sort_values(by='perc_pred_increase', ascending=False)
trading_df.columns

# %%
trading_df['pred_price'] = (trading_df['perc_pred_increase'] + 1) * trading_df['current_price']

# %%
#trading_df.loc[:,['name', 'mean_squared_error', 'r2_score', 'roi', 'perc_pred_increase','last_day', 'current_price']]

# %%
to_buy = trading_df.loc[~trading_df['name'].isin(bought['name'])].loc[:,['name', 'mean_squared_error', 'r2_score', 'roi', 'perc_pred_increase','last_day', 'current_price', 'pred_price']]
to_buy
# Out:
#                                  name  mean_squared_error  r2_score       roi  \
# 813             Black%20dragon%20mask        8.359696e+05  0.931644  1.079196
# 2616                  Frog%20slippers        2.221461e+07  0.960047  1.078733
# 566                    Molten%20glass        3.931459e+01  0.875348  1.072711
# 2895                 Dragon%20harpoon        6.581993e+08  0.856366  1.332873
# 2158                       Red%20bead        1.945137e+04  0.856609  1.346445
# 1974                    Raw%20lobster        1.869886e+02  0.870432  1.666840
# 2373  Dragon%20boots%20ornament%20kit        1.340257e+07  0.880747  1.060218
# 1903                  Team%20cape%20x        3.910958e+09  0.910630  1.364283
# 1679                             Logs        1.348888e+02  0.887860  1.792911
#
#       perc_pred_increase    last_day  current_price    pred_price
# 813             0.050376  2020-08-06        28100.0  2.951556e+04
# 2616            0.043556  2020-08-06       130210.0  1.358814e+05
# 566             0.043016  2020-08-06          116.0  1.209899e+02
# 2895            0.040301  2020-08-06       474534.0  4.936582e+05
# 2158            0.040103  2020-08-06         2567.0  2.669945e+03
# 1974            0.037130  2020-08-06          215.0  2.229829e+02
# 2373            0.036207  2020-08-06        51870.0  5.374804e+04
# 1903            0.031985  2020-08-06      2070510.0  2.136735e+06
# 1679            0.030923  2020-08-06           54.0  5.566985e+01

# %%
to_sell = trading_df.loc[trading_df['name'].isin(bought['name'])].loc[:,['name', 'mean_squared_error', 'r2_score', 'roi', 'perc_pred_increase','last_day', 'current_price', 'pred_price']]
to_sell
# Out:
#                                name  mean_squared_error  r2_score       roi  \
# 537                  Avantoe%20seed        1.721993e+04  0.888172  1.077821
# 162      Black%20wizard%20hat%20(g)        1.045895e+08  0.956981  1.222860
# 1868                     Iron%20ore        1.194075e+02  0.930788  3.374128
# 3020                Mole%20slippers        3.365397e+08  0.968196  2.013312
# 403           Black%20shield%20(h1)        1.932993e+05  0.934113  1.086539
# 1627          Wooden%20shield%20(g)        8.101713e+06  0.909752  1.090331
# 2469  Bottomless%20compost%20bucket        1.370366e+09  0.938613  1.206505
#
#       perc_pred_increase    last_day  current_price     pred_price
# 537             0.089764  2020-08-05          482.0     525.266290
# 162             0.045882  2020-08-06       278412.0  291186.168736
# 1868            0.026681  2020-08-06           78.0      80.081084
# 3020            0.026402  2020-08-06       493025.0  506042.075941
# 403             0.018047  2020-08-06         9198.0    9363.994217
# 1627            0.016458  2020-08-06        85373.0   86778.067837
# 2469           -0.045255  2020-08-06       308859.0  294881.514264

# %% [markdown]
# # Update with actual trades

# %%
bought.loc[11] = "Ahrim's%20robeskirt"

# %%
bought
# Out:
#                              name
# 0           Black%20shield%20(h1)
# 1                  Avantoe%20seed
# 2                      Iron%20ore
# 3      Black%20wizard%20hat%20(g)
# 4   Bottomless%20compost%20bucket
# 5                 Mole%20slippers
# 6           Wooden%20shield%20(g)
# 10            Ahrim's%20robeskirt

# %%
currently_buying = to_buy['name'][0:2]
currently_buying
# Out:
# 2499           Rune%20arrow
# 916     Ahrim's%20robeskirt
# Name: name, dtype: object

# %%
bought.merge(currently_buying, how='outer')
# Out:
#                             name
# 0          Black%20shield%20(h1)
# 1                 Avantoe%20seed
# 2                     Iron%20ore
# 3     Black%20wizard%20hat%20(g)
# 4  Bottomless%20compost%20bucket
# 5                Mole%20slippers
# 6          Wooden%20shield%20(g)

# %%
#bought = bought.merge(currently_buying, how='outer')

# %%
#bought = bought.drop([0,2,3])

# %%
#bought.loc[-1] = 'Bottomless%20compost%20bucket'

# %%
bought
# Out:
#                             name
# 0          Black%20shield%20(h1)
# 1                 Avantoe%20seed
# 2                     Iron%20ore
# 3     Black%20wizard%20hat%20(g)
# 4  Bottomless%20compost%20bucket
# 5                Mole%20slippers
# 6          Wooden%20shield%20(g)

# %%
#bought.merge(currently_buying)
bought.to_csv('data/bought', index=False)

# %%
pd.read_csv('data/bought')
# Out:
#                             name
# 0          Black%20shield%20(h1)
# 1                 Avantoe%20seed
# 2                     Iron%20ore
# 3     Black%20wizard%20hat%20(g)
# 4  Bottomless%20compost%20bucket
# 5                Mole%20slippers
# 6          Wooden%20shield%20(g)
# 7            Ahrim's%20robeskirt

# %%
trading_

# %%
trading_df.loc[:,['name', 'mean_squared_error', 'r2_score', 'roi', 'perc_pred_increase','last_day']].to_csv('data/trading_8.2.csv')

# %% [markdown]
# # fastai tabular data

# %%
procs = [Normalize]

# %%
valid_idx = range(int(len(df)*.8), len(df)-60)

# %%
dep_var = 'Y'

# %%
path = Path(f'./data/wiki_urls/{item_name}')

# %%
trimmed_df['date_obj'] = trimmed_df.index

# %%
trimmed_df['date_obj'] = trimmed_df['date_obj'].apply(lambda x: pd.to_datetime(x))

# %%
time_trimmed_df = trimmed_df.loc[trimmed_df['date_obj'] > pd.to_datetime('2018-05-01')]

# %%
time_trimmed_df[item_name].plot()

# %%
time_trimmed_df = time_trimmed_df.drop(columns=['date_obj'], axis=1)

# %%
trimmed_df = time_trimmed_df

# %%
df = trimmed_df

# %%
df

# %%
data = TabularDataBunch.from_df(path, df, dep_var, valid_idx=valid_idx, procs=procs, cat_names=[])

# %%
learn = tabular_learner(data, layers=[500,100], emb_szs={'native-country': 10}, metrics=mean_squared_error)

# %%
data.show_batch()

# %%
learn.save('stage-0')

# %%
learn.lr_find(end_lr=1e3)

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(5, max_lr=1e-2)

# %%
learn.fit_one_cycle(5, max_lr=1e-2)

# %%
learn.show_results(ds_type=DatasetType.Train)

# %%
learn.save('stage-1')

# %%
learn = learn.load('stage-1')

# %%
learn.lr_find()

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(5, 3e-5)

# %%
learn.show_results(ds_type=DatasetType.Train)

# %%
learn.save('stage-2')

# %%
learn.lr_find()

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(5, 3e-6)

# %%
learn.save('stage-3')

# %%
learn.show_results(ds_type=DatasetType.Train)

# %%
learn.lr_find()
learn.recorder.plot()

# %%
learn.fit_one_cycle(5, 3e-4)

# %%
learn.save('stage-4')

# %%
learn.lr_find(end_lr=1e2)
learn.recorder.plot()

# %%
learn.show_results(ds_type=DatasetType.Train)

# %%
learn.fit_one_cycle(10, 1e-4)

# %%
learn = learn.load('stage-4')

# %%
learn.show_results(ds_type=DatasetType.Train)

# %% [markdown]
# # Plot results

# %%
int(learn.predict(df.iloc[0])[1])

# %%
learn.predict(df.iloc[0])

# %%
plot_x = [float(learn.predict(df.iloc[i])[1]) for i in range(len(df))]

# %%
plot_y = df['Y']

# %%
plot_y

# %%
plot_x

# %%
plot_df = pd.DataFrame(plot_y)

# %%
plot_df['x'] = plot_x

# %%
plot_df.head()

# %%
plot_df.plot()

# %%
plt.plot(plot_x)

# %%
plt.plot(plot_y)

# %%
plt.plot(range(len(plot_x)),np.array([plot_x,plot_y]).T)

# %%
len(plot_x)

# %%
plt.plot(range(len(plot_x[len(plot_x)-60:])), np.array([plot_x[len(plot_x)-60:], plot_y[len(plot_y)-60:]]).T)
plt.legend()

# %%
plt.plot(plot_x[len(plot_x)-60:])

# %%
len(plot_x)

# %%
plt.plot(plot_y[len(plot_y)-60:])

# %%
x_series = pd.Series(plot_x, name='Predict')

# %%
type(x_series)

# %%
type(plot_y)

# %%
y_series = plot_y.reindex(x_series.index)

# %%
y_series

# %%
x_series

# %%
pd.concat([y_series, x_series],  axis=1).iloc[1705-60:].plot()

# %%
learn.drop

# %%
learn.save('stage-final')
learn.export()

# %% [markdown]
# # Load in the full data (recent rows will have been dropped because Ys were N/A)

# %%
prediction_df = item_df_training

# %%
prediction_df['constant'] = time_trimmed_df['Y'].mean() *scaling_factor

# %%
prediction_df.columns

# %%
prediction_df = prediction_df.fillna(method='ffill').fillna(method='bfill').fillna(0)

# %%
predict_data = TabularDataBunch.from_df(path, prediction_df, dep_var, valid_idx=valid_idx, procs=procs, cat_names=[])

# %%
predict_learn = tabular_learner(data, layers=[500,100], emb_szs={'native-country': 10}, metrics=mean_squared_error)

# %%
predict_learn =predict_learn.load('stage-final')

# %%
predict_learn.show_results(ds_type=DatasetType.Train)

# %%
predict_learn.predict(prediction_df.iloc[0])

# %%
predict_learn.predict(prediction_df.iloc[100])

# %%
prediction_df

# %%
predictions = [float(predict_learn.predict(prediction_df.iloc[i])[1]) for i in range(len(prediction_df))]

# %%
predictions

# %%
prediction_df.tail()

# %%
prediction_df['predictions'] = predictions

# %%
prediction_df['predictions'].tail(30)

# %%
prediction_df

# %% [markdown]
# ####
