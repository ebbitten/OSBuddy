# %%
import pandas as pd
data = pd.read_csv('osbHistroic.csv', sep = ",", header = 0, index_col = 0, nrows = 20)

# %%
print(data)
# Out:
#                                                                                 30240000000  \
# buyingPrice;buyingCompleted;sellingPrice;sellin...
# 2                                                   186;18711020;186;17647811;186;36358831;
# 6                                                      169431;1425;174560;3038;172923;4463;
# 12289                                                           5618;165;3483;309;4226;474;
# 8                                                       178060;764;179231;1860;178890;2624;
# 10                                                     188708;1146;186067;2838;186827;3984;
# 12                                                     193832;1153;189636;2843;190847;3996;
# 12291                                                           7162;276;6991;501;7052;777;
# 28                                                                  521;390;59;414;283;804;
# 30                                                            975;1899;1045;1655;1008;3554;
# ...
